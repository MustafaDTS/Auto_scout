# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid"
# alt="CLRSWY"></p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#9d4f8c; font-size:100%; text-align:center; border-radius:10px 10px;">WAY TO REINVENT YOURSELF</p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#060108; font-size:200%; text-align:center; border-radius:10px 10px;">DA & DVwPY</p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#060108; font-size:200%; text-align:center; border-radius:10px 10px;">The Exploratory Data Analysis (EDA) Project</p>
#
# <img src=https://i.ibb.co/wJW61Y2/Used-cars.jpg width="700" height="200">
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#060108; font-size:200%; text-align:center; border-radius:10px 10px;">AutoScout Car Price Prediction EDA</p>

# %% [markdown]
# ## Introduction
# Welcome to "***AutoScout Exploratory Data Analysis (EDA) Project***". This is the project of completing ***Data Analysis & Data Visualization*** Courses and a successful hand-over is mandatory for getting certification for both courses. **Auto Scout** data used in this project scraped from the Website of an online car trading company in 2022, and contains many features of 13 different car makes including 594 models. In this project, you will have the opportunity to apply many commonly used algorithms for Data Cleaning and Exploratory Data Analysis by using a variety of Python libraries, such as Numpy, Pandas, Matplotlib, Seaborn, Scipy, and then you will get a clean dataset for your analysis and pretictive modelling in Machine Learning Path. So you will have the chance to use all the skills you have already learned in the Data Analysis and Visualization courses.
#
# **``In this context, the project consists of 3 parts in general:``**
# * **The first part** is related to ``'Data Cleaning'``. It deals with Incorrect Headers, Incorrect Format, Anomalies, and Dropping useless columns.
# * **The second part** is related to ``'Filling Data'``, in other words 'Imputation'. It deals with Missing Values. Categorical to numeric transformation, Encoding, is done as well.
# * **The third part** is related to ``'Handling Outliers of Data'`` via Visualization libraries. So, some insights will be extracted.
#
# **``SPECIAL NOTE:``**  However, you are ``free to create your own style``. You do ``NOT`` have to stick to the steps above. Nevertheless, we, the DA & DV instructors, recommend you study each part separately to create a source notebook for your further studies.
#
# In order to build your Portfolio in terms of the GitHub account, you need to push your solution file up to your own repository.
#
# Please after solving the task, commit your notebook to GitHub and submit its link to LMS page where the project is settled down.
#
# **BE NOTED:** Please ``DO NOT FORGET`` to click the submit button.
#
# ### Some Reminders on Exploratory data analysis (EDA)
#
# Exploratory data analysis (EDA) is an especially important activity in the routine of a data analyst or scientist. It enables an in depth understanding of the dataset, define or discard hypotheses and create predictive models on a solid basis. It uses data manipulation techniques and several statistical tools to describe and understand the relationship between variables and how these can impact business. By means of EDA, we can obtain meaningful insights that can impact analysis under the following questions (If a checklist is good enough for pilots to use every flight, it’s good enough for data scientists to use with every dataset).
# 1. What question are you trying to solve (or prove wrong)?
# 2. What kind of data do you have?
# 3. What’s missing from the data?
# 4. Where are the outliers?
# 5. How can you add, change or remove features to get more out of your data?
#
# **``Exploratory data analysis (EDA)``** is often an **iterative brainstorming process** where you pose a question, review the data, and develop further questions to investigate before beginning model development work. The image below shows how the brainstorming phase is connected with that of understanding the variables and how this in turn is connected again with the brainstorming phase.<br>
#
# <img src=https://i.ibb.co/k0MC950/EDA-Process.png width="300" height="100">
#
# [Image Credit: Andrew D.](https://towardsdatascience.com/exploratory-data-analysis-in-python-a-step-by-step-process-d0dfa6bf94ee)

# %% [markdown]
# # PART- 1 `(Data Cleaning)`

# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
# pd.options.display.max_rows = 80
# pd.options.display.max_columns = 80

pd.set_option('display.max_columns', 175)
pd.set_option('display.max_rows', 175)
pd.set_option('display.min_rows', 175)

# %%
# pd.set_option('display.max_rows', None)

# %%
df = pd.read_json("as24_cars.zip")

df0 = df.copy() 

# df = pd.read_json("as24_cars.json") #after extract from zip

# %%
df.sample(5).T
# Out:
#                                                                        16767  \
# make_model                                                     Dacia Sandero
# short_description                                       1.0 SCe 75ch Evasion
# make                                                               \nDacia\n
# model                                                      [\n, Sandero ,\n]
# location                                                    10000 Troyes, FR
# price                                                             € 12,990.-
# Body type                                                    [\n, Sedan, \n]
# Type                                                          [\n, Used, \n]
# Doors                                                            [\n, 5, \n]
# Country version                                                          NaN
# Offer number                                  [\n, star-FW-657-TR_21125, \n]
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29480 entries, 0 to 29479
# Data columns (total 58 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   make_model                28630 non-null  object
#  1   short_description         28630 non-null  object
#  2   make                      28630 non-null  object
#  3   model                     28630 non-null  object
#  4   location                  28630 non-null  object
#  5   price                     28630 non-null  object
#  6   Body type                 28630 non-null  object
#  7   Type                      28630 non-null  object
#  8   Doors                     28271 non-null  object
#  9   Country version           16889 non-null  object
#  10  Offer number              23100 non-null  object
#  11  Warranty                  15784 non-null  object
#  12  Mileage                   28629 non-null  object
# ...

# %%
df.shape
# Out:
# (29480, 58)

# %%
df.isna().sum()
# Out:
# make_model                     850
# short_description              850
# make                           850
# model                          850
# location                       850
# price                          850
# Body type                      850
# Type                           850
# Doors                         1209
# Country version              12591
# Offer number                  6380
# Warranty                     13696
# Mileage                        851
# First registration             852
# Gearbox                       1098
# Fuel type                     2637
# Colour                        2574
# Paint                        14985
# desc                          1433
# seller                         850
# Seats                         3975
# Power                         1422
# Engine size                   2253
# Gears                        10526
# CO₂-emissions                10886
# Manufacturer colour           7693
# Drivetrain                   12587
# ...

# %% [markdown]
# ## Normalise the column names

# %%
import skimpy

# %%
df = skimpy.clean_columns(df)
# Out:
# 50 column names have been cleaned

# %%
df.sample(3).T
# Out:
#                                                                      2639   \
# make_model                                                      Opel Corsa
# short_description        F Elegance Matrix-LED*Kamera*SHZ*PDC*Klima*Nav...
# make                                                              \nOpel\n
# model                                                      [\n, Corsa ,\n]
# location                 Friedrich-Ebert-Straße 27,  41352 Korschenbroi...
# price                                                           € 17,740.-
# body_type                                                [\n, Compact, \n]
# type                                                        [\n, Used, \n]
# doors                                                          [\n, 5, \n]
# country_version                                                        NaN
# offer_number                                             [\n, 6077252, \n]
# ...

# %%
df.rename(columns = {"comfort_&_convenience":"comfort_convenience",
                     "entertainment_&_media":"entertainment_media",
                     "safety_&_security":"safety_security"
                    }, inplace = True)

# %%
df.columns
# Out:
# Index(['make_model', 'short_description', 'make', 'model', 'location', 'price',
#        'body_type', 'type', 'doors', 'country_version', 'offer_number',
#        'warranty', 'mileage', 'first_registration', 'gearbox', 'fuel_type',
#        'colour', 'paint', 'desc', 'seller', 'seats', 'power', 'engine_size',
#        'gears', 'co_emissions', 'manufacturer_colour', 'drivetrain',
#        'cylinders', 'fuel_consumption', 'comfort_convenience',
#        'entertainment_media', 'safety_security', 'extras', 'empty_weight',
#        'model_code', 'general_inspection', 'last_service',
#        'full_service_history', 'non_smoker_vehicle', 'emission_class',
#        'emissions_sticker', 'upholstery_colour', 'upholstery',
#        'production_date', 'previous_owner', 'other_fuel_types',
#        'power_consumption', 'energy_efficiency_class', 'co_efficiency',
#        'fuel_consumption_wltp', 'co_emissions_wltp', 'available_from',
# ...

# %% [markdown]
# ### Before analysing each column 1-by-1 check the null_sum and null_percentage for each column

# %%
null_sum = pd.DataFrame(df.isna().sum(), columns = ["null_sum"])
# null_sum
null_perc = round(pd.DataFrame(df.isna().sum()/df.shape[0]*100 , columns = ["null_perc"]),3)
# null_perc 

null_summary = pd.concat([null_sum,null_perc], axis= 1).reset_index().rename(columns = {"index":"col_names"})
null_summary
# Out:
#                   col_names  null_sum  null_perc
# 0                make_model       850      2.883
# 1         short_description       850      2.883
# 2                      make       850      2.883
# 3                     model       850      2.883
# 4                  location       850      2.883
# 5                     price       850      2.883
# 6                 body_type       850      2.883
# 7                      type       850      2.883
# 8                     doors      1209      4.101
# 9           country_version     12591     42.710
# 10             offer_number      6380     21.642
# 11                 warranty     13696     46.459
# 12                  mileage       851      2.887
# 13       first_registration       852      2.890
# 14                  gearbox      1098      3.725
# 15                fuel_type      2637      8.945
# 16                   colour      2574      8.731
# 17                    paint     14985     50.831
# ...

# %% [markdown]
# ## Define a function to identify columns with null values over 80%

# %%
def Null_over_limit(df,limit):
    null_per = df.isna().sum()/df.shape[0]*100
    return null_per.loc[lambda x : x >= limit]

# %%
Null_over_limit(df,80)
# Out:
# last_service               93.205563
# other_fuel_types           92.154003
# power_consumption          98.253053
# fuel_consumption_wltp      99.660787
# co_emissions_wltp          99.606513
# available_from             98.666893
# taxi_or_rental_car         98.568521
# availability               98.978969
# last_timing_belt_change    98.059701
# electric_range_wltp        99.945726
# power_consumption_wltp     99.945726
# battery_ownership          99.976255
# dtype: float64

# %% [markdown]
# ### Drop columns with null values over 80%

# %%
drop_col_names = Null_over_limit(df,80).index
drop_col_names
# Out:
# Index(['last_service', 'other_fuel_types', 'power_consumption',
#        'fuel_consumption_wltp', 'co_emissions_wltp', 'available_from',
#        'taxi_or_rental_car', 'availability', 'last_timing_belt_change',
#        'electric_range_wltp', 'power_consumption_wltp', 'battery_ownership'],
#       dtype='object')

# %%
df.drop(columns = drop_col_names, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29480 entries, 0 to 29479
# Data columns (total 46 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   make_model               28630 non-null  object
#  1   short_description        28630 non-null  object
#  2   make                     28630 non-null  object
#  3   model                    28630 non-null  object
#  4   location                 28630 non-null  object
#  5   price                    28630 non-null  object
#  6   body_type                28630 non-null  object
#  7   type                     28630 non-null  object
#  8   doors                    28271 non-null  object
#  9   country_version          16889 non-null  object
#  10  offer_number             23100 non-null  object
#  11  warranty                 15784 non-null  object
#  12  mileage                  28629 non-null  object
#  13  first_registration       28628 non-null  object
# ...

# %% [markdown]
# ### Check if the colums are list type

# %%
list_columns_init = []

# %%
# for i in df.columns:
#     for y in df[i].sample(25000):
#         if "]" in str(y):
#             if i not in list_columns_init:
#                 list_columns_init.append(i)    

for i in df.columns:
    for y in df[i].sample(25000):
        if type(y)==list:
            if i not in list_columns_init:
                list_columns_init.append(i)

# %%
list_columns_init
# Out:
# ['model',
#  'body_type',
#  'type',
#  'doors',
#  'country_version',
#  'offer_number',
#  'warranty',
#  'gearbox',
#  'desc',
#  'seats',
#  'power',
#  'engine_size',
#  'gears',
#  'drivetrain',
#  'cylinders',
#  'fuel_consumption',
#  'comfort_convenience',
#  'entertainment_media',
#  'safety_security',
#  'extras',
#  'empty_weight',
#  'model_code',
#  'previous_owner']

# %% [markdown]
# # Start to examine each column 1-by-1
# Examine, clean and decide to keep or drop them

# %% [markdown]
# Define a function to show null percentage of each column

# %%
def show_null_perc(Serial):
    perc = round(Serial.isna().sum()/Serial.shape[0]*100,2)
    return perc

# %% [markdown]
# ## make_model

# %%
df.make_model.value_counts(dropna=False)
# Out:
# Renault Megane              863
# NaN                         850
# SEAT Leon                   787
# Volvo V40                   740
# Dacia Sandero               730
# Hyundai i30                 706
# Volvo C70                   692
# Opel Astra                  675
# Ford Mustang                663
# Peugeot 308                 537
# Ford Focus                  495
# Nissan Qashqai              490
# SEAT Ibiza                  442
# Fiat 500                    440
# Fiat Tipo                   430
# Renault Clio                417
# Ford Fiesta                 400
# Nissan Micra                390
# Fiat 500X                   376
# Skoda Octavia               371
# Opel Corsa                  366
# Volvo XC60                  364
# Dacia Duster                349
# Toyota Yaris                332
# Volvo V60                   309
# Opel Insignia               290
# Peugeot 208                 262
# Skoda Fabia                 251
# Fiat 500C                   249
# ...

# %%
show_null_perc(df.make_model)
# Out:
# 2.88

# %%
# find number of different make_model
df.make_model.value_counts(dropna=False).index.nunique()
# Out:
# 611

# %% [markdown]
# ## make

# %%
df.make.value_counts(dropna=False)
# Out:
# \nVolvo\n            3659
# \nMercedes-Benz\n    2398
# \nOpel\n             2385
# \nPeugeot\n          2360
# \nRenault\n          2351
# \nFiat\n             2338
# \nFord\n             2324
# \nNissan\n           2064
# \nToyota\n           2038
# \nHyundai\n          1867
# \nSEAT\n             1743
# \nSkoda\n            1566
# \nDacia\n            1537
# NaN                   850
# Name: make, dtype: int64

# %% [markdown]
# #### Clear the entries (get rid of \n)

# %%
df.make = df.make.str.strip("\n")

# %%
df.make.value_counts(dropna=False)
# Out:
# Volvo            3659
# Mercedes-Benz    2398
# Opel             2385
# Peugeot          2360
# Renault          2351
# Fiat             2338
# Ford             2324
# Nissan           2064
# Toyota           2038
# Hyundai          1867
# SEAT             1743
# Skoda            1566
# Dacia            1537
# NaN               850
# Name: make, dtype: int64

# %% [markdown]
# Check number of different makes

# %%
df.make.value_counts(dropna=False).index.nunique(dropna=False)
# Out:
# 14

# %% [markdown]
# ## model

# %%
df.model.value_counts(dropna = False)
# Out:
# [\n, Megane ,\n]               863
# NaN                            850
# [\n, Leon ,\n]                 787
# [\n, V40 ,\n]                  740
# [\n, Sandero ,\n]              730
# [\n, i30 ,\n]                  706
# [\n, C70 ,\n]                  692
# [\n, Astra ,\n]                675
# [\n, Mustang ,\n]              663
# [\n, 308 ,\n]                  537
# [\n, Focus ,\n]                495
# [\n, Qashqai ,\n]              490
# [\n, 500 ,\n]                  443
# [\n, Ibiza ,\n]                442
# [\n, Tipo ,\n]                 430
# [\n, Clio ,\n]                 417
# [\n, Fiesta ,\n]               400
# [\n, Micra ,\n]                390
# [\n, 500X ,\n]                 376
# [\n, Octavia ,\n]              371
# [\n, Corsa ,\n]                366
# [\n, XC60 ,\n]                 364
# [\n, Duster ,\n]               349
# [\n, Yaris ,\n]                332
# [\n, V60 ,\n]                  309
# [\n, Insignia ,\n]             290
# [\n,  ,\n]                     276
# ...

# %% [markdown]
# #### Clean the entries (they are given as list)

# %%
type(df.model.iloc[1])
# Out:
# list

# %%
import re

# %%
# #test to extract the pattern
# re.findall(", ([A-Za-z 0-9]+)", "[\n, CLS 450 ,\n]")[0].rstrip()
# re.findall(", ([A-Za-z\s 0-9]+)", "[\n,  ,\n]")[0]
# df['model'].str[0].strip("\n")

# %%
df['model'] = df['model'].astype("str").apply(lambda x :re.findall(", ([A-Za-z 0-9]+)", x)[0].rstrip() if len(re.findall(", ([A-Za-z 0-9]+)", x))>0 else np.nan)

# %%
df.model.value_counts(dropna=False)
# Out:
# Megane               863
# NaN                  850
# Leon                 787
# V40                  740
# Sandero              730
# i30                  706
# C70                  692
# Astra                675
# Mustang              663
# 308                  537
# Qashqai              498
# Focus                495
# 500                  443
# Ibiza                442
# Tipo                 430
# Clio                 417
# Fiesta               400
# Micra                390
# 500X                 376
# Octavia              371
# Corsa                370
# XC60                 364
# Duster               349
# Yaris                332
# V60                  309
# Insignia             290
#                      276
# 208                  262
# Fabia                251
# 500C                 249
# C30                  231
# Auris                231
# Coupe                226
# RCZ                  220
# TUCSON               218
# 3008                 217
# Kuga                 210
# ...

# %%
df.model.isnull().sum()
# Out:
# 850

# %%
df.model.dtype
# Out:
# dtype('O')

# %%
df['model'] = df['model'].replace("",np.nan)

# %%
df.model.value_counts(dropna=False)
# Out:
# NaN                  1126
# Megane                863
# Leon                  787
# V40                   740
# Sandero               730
# i30                   706
# C70                   692
# Astra                 675
# Mustang               663
# 308                   537
# Qashqai               498
# Focus                 495
# 500                   443
# Ibiza                 442
# Tipo                  430
# Clio                  417
# Fiesta                400
# Micra                 390
# 500X                  376
# Octavia               371
# Corsa                 370
# XC60                  364
# Duster                349
# Yaris                 332
# V60                   309
# Insignia              290
# 208                   262
# Fabia                 251
# 500C                  249
# C30                   231
# Auris                 231
# Coupe                 226
# RCZ                   220
# TUCSON                218
# 3008                  217
# ...

# %%
df.model.value_counts(dropna=False).index.nunique(dropna=False)
# Out:
# 585

# %%
# df['model'].astype("str").apply(lambda x : x.replace("",np.nan) if x == "" else x)

# %% [markdown]
# #### Compare nulls for make-model-make_mode

# %%
df[df["model"].isnull() & df["make"].notnull()][["make","model"]].index.shape
# Out:
# (276,)

# %%
df[df["make"].isnull() & df["model"].notnull()][["make","model"]].index.shape
# Out:
# (0,)

# %%
df[df["make"].isnull() & df["make_model"].notnull()][["make","make_model"]].index.shape
# Out:
# (0,)

# %%
df[df["model"].isnull() & df["make_model"].notnull()][["model","make_model"]].index.shape
# Out:
# (276,)

# %% [markdown]
# Note: make has 14 features, model has 585 features, make_model has 611 features. Also make has less null (no gain to keep other). Drop model and make_model.

# %%
df.drop("model", axis=1, inplace=True)

# %%
df.drop("make_model", axis=1, inplace=True)

# %% [markdown]
# ## short_description

# %%
df.short_description.value_counts(dropna= False)
# Out:
# NaN                                                   850
#                                                       213
# D2 Momentum 120                                        88
# D2 Kinetic 120                                         87
# Cabrio 1.4T S&S Excellence                             85
# Extreme+ 7-Sitzer TCe 110                              57
# SW 1.6 Multijet II Lounge                              41
# 1.2 Lounge                                             38
# D3 Momentum Aut. 150                                   34
# D4 R-Design Kinetic 190                                34
# D3 Kinetic 150                                         34
# D2 Kinetic Aut. 115                                    32
# D3 Momentum 150                                        31
# 2.0 TGDI N Performance 275                             28
# 0.9 TCE Stepway Ambiance 66kW                          26
# 180d 7G-DCT                                            25
# ...

# %%
df.short_description.value_counts(dropna= False).index.nunique(dropna=False)
# Out:
# 20948

# %%
df.drop("short_description", axis=1, inplace=True)

# %% [markdown]
# It seems we can drop this (since some info is repeated by other coloumns and it has too many different values).

# %% [markdown]
# ## desc
# Describe the advert

# %%
df.desc.value_counts(dropna=False)
# Out:
# NaN                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   
# ...

# %%
df.desc.astype("str").nunique() #original dytpe is int
# Out:
# 23242

# %%
df.drop("desc", axis=1, inplace=True)

# %% [markdown]
# Seems not very useful (better to drop)

# %% [markdown]
# ## location

# %%
df.location.value_counts(dropna=False)
# Out:
# NaN                                                                                                           850
# Av. Laboral, 10,  28021 MADRID, ES                                                                            306
# Luckenwalder Berg 5,  14913 Jüterbog, DE                                                                      170
# Ctra. del Mig, 96,,  08097 L'Hospitalet de Llobregat, ES                                                      146
# 9 boulevard Jules Ferry,  75011 Paris, FR                                                                     142
# Neuenhofstr. 77,  52078 Aachen, DE                                                                            135
# Bestel gemakkelijk Online 24/7,  1000 Brussel, BE                                                             131
# CARRETERA DE MATARO 10,  8903 SANT ADRIÀ DE BESÒS, ES                                                         110
# ...

# %%
# df['location'].astype("str").apply(lambda x : x[-3:]).value_counts(dropna=False)

# %%
df['location'] = df['location'].astype("str").apply(lambda x : x[-3:])
df['location']
# Out:
# 0         ES
# 1         ES
# 2         ES
# 3         ES
# 4         ES
# 5         DE
# 6         ES
# 7         ES
# 8         BE
# 9         ES
# 10        BE
# 11        ES
# 12        ES
# 13        BE
# 14        ES
# 15        DE
# 16        BE
# 17        ES
# 18        ES
# 19        ES
# 20        ES
# 21        ES
# 22        ES
# 23        BE
# 24        ES
# 25        ES
# 26        ES
# 27        BE
# 28        ES
# 29        DE
# 30        BE
# 31        BE
# 32        ES
# 33        ES
# 34        ES
# 35        ES
# 36        ES
# 37        ES
# 38        BE
# 39        BE
# 40        ES
# 41        BE
# 42        DE
# 43        ES
# 44        ES
# 45        ES
# 46        ES
# 47        ES
# 48        ES
# 49        DE
# 50        ES
# 51        ES
# 52        ES
# 53        ES
# 54        ES
# 55        BE
# 56        ES
# 57        ES
# 58        DE
# 59        BE
# 60        ES
# 61        ES
# 62        BE
# 63        DE
# 64        ES
# 65        DE
# ...

# %%
df['location'].value_counts(dropna = False)
# Out:
#  DE    12643
#  ES     6517
#  NL     2929
#  IT     2497
#  BE     1873
#  FR     1473
# nan      850
#  AT      660
#  LU       35
#  DK        1
#  EE        1
#  BG        1
# Name: location, dtype: int64

# %%
df['location'].value_counts(dropna = False).index.nunique(dropna = False)
# Out:
# 12

# %% [markdown]
# Most of them Germany, I replaced open address by only country short name

# %%
df['location'].dtype
# Out:
# dtype('O')

# %%
show_null_perc(df['location'])
# Out:
# 0.0

# %% [markdown]
# ## price (target value)

# %%
df.price.isnull().sum()
# Out:
# 850

# %%
df.price
# Out:
# 0        € 16,950.-
# 1        € 80,900.-
# 2        € 69,900.-
# 3        € 46,990.-
# 4        € 16,800.-
# 5         € 4,690.-
# 6        € 22,550.-
# 7        € 26,900.-
# 8        € 44,999.-
# 9        € 23,900.-
# 10       € 14,200.-
# 11       € 37,999.-
# 12       € 23,999.-
# 13       € 24,400.-
# 14       € 16,999.-
# 15        € 7,450.-
# 16       € 38,999.-
# 17       € 41,900.-
# 18       € 29,800.-
# 19       € 37,490.-
# 20       € 21,000.-
# 21       € 26,800.-
# 22       € 32,900.-
# 23       € 32,950.-
# 24       € 64,900.-
# 25       € 21,000.-
# 26       € 67,900.-
# 27       € 13,999.-
# 28       € 29,990.-
# 29        € 8,300.-
# 30       € 32,950.-
# 31       € 32,950.-
# 32       € 36,900.-
# 33       € 29,800.-
# 34       € 18,390.-
# 35       € 25,900.-
# 36       € 25,400.-
# 37       € 29,000.-
# 38       € 29,900.-
# 39       € 14,490.-
# 40       € 20,630.-
# 41       € 27,500.-
# 42        € 8,490.-
# 43       € 23,850.-
# 44       € 35,500.-
# ...

# %%
float('%.2f'% float(re.findall("([,0-9]+)", "€ 149,950.-")[0].replace(",", "")))
# Out:
# 149950.0

# %%
# #test
# re.findall("([0-9]+)", "€ 26,890.-")
# re.findall("([,0-9]+)", "NaN")

# %%
df["price"] = df["price"].astype("str").apply(lambda x : float('%.2f'% float(re.findall("([,0-9]+)", x)[0].replace(",", ""))) if x.startswith("€") else np.nan)

# %%
df["price"].sort_values()
# Out:
# 5876      490.0
# 5540      500.0
# 20045     500.0
# 17883     590.0
# 5314      600.0
# 5375      600.0
# 5319      699.0
# 24471     700.0
# 3384      700.0
# 5546      740.0
# 7871      750.0
# 5302      750.0
# 25250     750.0
# 20632     750.0
# 6502      790.0
# 2506      790.0
# 7895      790.0
# 5657      790.0
# 3155      799.0
# 3466      800.0
# 10759     800.0
# 5295      800.0
# 8250      800.0
# 12172     850.0
# 4003      850.0
# 5364      888.0
# 5344      890.0
# 7901      890.0
# 5425      890.0
# 7741      890.0
# 3406      900.0
# 7876      900.0
# 3411      900.0
# 7798      944.0
# 5435      944.0
# 7767      950.0
# 7435      950.0
# 7390      950.0
# 7746      950.0
# 7847      950.0
# 10541     950.0
# 10649     950.0
# 7818      950.0
# 5400      995.0
# 23911     999.0
# 20054     999.0
# 7747      999.0
# 7782      999.0
# 9105      999.0
# 3506      999.0
# 2658      999.0
# 4255      999.0
# 8090      999.0
# 8936      999.0
# 5308      999.0
# ...

# %%
df["price"].dtype
# Out:
# dtype('float64')

# %%
df["price"].isnull().sum()
# Out:
# 850

# %%
df["price"].max()
# Out:
# 1346900.0

# %%
sns.boxplot(df.price);

# %%
sns.distplot(df.price);
# Out:
# /var/folders/2f/xj4f91y93gg9jhgml0djwyjm0000gp/T/ipykernel_7069/689887770.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.price);

# %% [markdown]
# Price is target value also only 2.883% null, dorp null rows from df

# %%
df = df.dropna(subset = ["price"])

# %%
df.shape
# Out:
# (28630, 42)

# %% [markdown]
# ## body_type

# %%
df["body_type"].value_counts(dropna=False)
# Out:
# [\n, Station wagon, \n]       5448
# [\n, Off-Road/Pick-up, \n]    5415
# [\n, Compact, \n]             5387
# [\n, Sedan, \n]               5043
# [\n, Coupe, \n]               4009
# [\n, Convertible, \n]         3328
# Name: body_type, dtype: int64

# %%
# df.body_type[0][0].split(",")[1]
# df.body_type[0].astype(str).split(",")

# %%
df["body_type"] = df["body_type"].str[0].str.strip("\n").str.replace(",","")

# %%
df["body_type"]
# Out:
# 0         Compact
# 1         Compact
# 2         Compact
# 3         Compact
# 4         Compact
# 5         Compact
# 6         Compact
# 7         Compact
# 8         Compact
# 9         Compact
# 10        Compact
# 11        Compact
# 12        Compact
# 13        Compact
# 14        Compact
# 15        Compact
# 16        Compact
# 17        Compact
# 18        Compact
# 19        Compact
# 20        Compact
# 21        Compact
# 22        Compact
# 23        Compact
# 24        Compact
# 25        Compact
# 26        Compact
# 27        Compact
# 28        Compact
# 29        Compact
# 30        Compact
# 31        Compact
# 32        Compact
# 33        Compact
# 34        Compact
# 35        Compact
# 36        Compact
# 37        Compact
# 38        Compact
# 39        Compact
# 40        Compact
# 41        Compact
# 42        Compact
# 43        Compact
# 44        Compact
# 45        Compact
# 46        Compact
# 47        Compact
# 48        Compact
# 49        Compact
# ...

# %%
df["body_type"].value_counts(dropna=False)
# Out:
#  Station wagon        5448
#  Off-Road/Pick-up     5415
#  Compact              5387
#  Sedan                5043
#  Coupe                4009
#  Convertible          3328
# Name: body_type, dtype: int64

# %%
df.body_type.dtype
# Out:
# dtype('O')

# %%
df.body_type.value_counts(dropna=False).index.nunique(dropna=False)
# Out:
# 6

# %%
show_null_perc(df.body_type)
# Out:
# 0.0

# %% [markdown]
# ## type

# %%
df.type.value_counts(dropna=False)
# Out:
# [\n, Used, \n]              25251
# [\n, Demonstration, \n]      1433
# [\n, Pre-registered, \n]     1377
# [\n, Employee's car, \n]      569
# Name: type, dtype: int64

# %%
df.type = df.type.str[0].str.strip("\n").str.replace(",","")
df.type
# Out:
# 0                   Used
# 1         Pre-registered
# 2                   Used
# 3                   Used
# 4                   Used
# 5                   Used
# 6                   Used
# 7                   Used
# 8                   Used
# 9                   Used
# 10                  Used
# 11                  Used
# 12                  Used
# 13                  Used
# 14                  Used
# 15                  Used
# 16                  Used
# 17                  Used
# 18                  Used
# 19                  Used
# 20                  Used
# 21                  Used
# 22        Pre-registered
# 23                  Used
# 24                  Used
# 25                  Used
# 26                  Used
# 27                  Used
# 28                  Used
# 29                  Used
# 30                  Used
# 31                  Used
# 32                  Used
# 33                  Used
# 34                  Used
# 35                  Used
# 36                  Used
# ...

# %%
df.type.value_counts(dropna= False)
# Out:
#  Used               25251
#  Demonstration       1433
#  Pre-registered      1377
#  Employee's car       569
# Name: type, dtype: int64

# %%
df.type.dtype
# Out:
# dtype('O')

# %%
df.type.value_counts(dropna= False).index.nunique(dropna=False)
# Out:
# 4

# %%
show_null_perc(df.type)
# Out:
# 0.0

# %% [markdown]
# #### Function to clean similar columns

# %%
def pick_from_list(Series):
    Series = Series.str[0].str.strip("\n").str.replace(",","")
    return Series

# %% [markdown]
# ## doors

# %%
df.doors.value_counts(dropna=False)
# Out:
# [\n, 5, \n]    17481
# [\n, 2, \n]     5523
# [\n, 4, \n]     3001
# [\n, 3, \n]     2259
# NaN              359
# [\n, 6, \n]        5
# [\n, 1, \n]        2
# Name: doors, dtype: int64

# %%
df.doors = pick_from_list(df.doors)
df.doors
# Out:
# 0         5
# 1         4
# 2         5
# 3         5
# 4         5
# 5         3
# 6         5
# 7         5
# 8         5
# 9         5
# 10        5
# 11        5
# 12        5
# 13        5
# 14        5
# 15        4
# 16        4
# 17        5
# 18        5
# 19        5
# 20        5
# 21        4
# 22        5
# 23        5
# 24        5
# 25        5
# 26        5
# 27        5
# 28        5
# 29        4
# 30        4
# 31        5
# 32        5
# 33        4
# 34        5
# 35        5
# 36        5
# 37        5
# 38        4
# 39        5
# 40        5
# 41        5
# 42        5
# 43        5
# 44        5
# 45        5
# 46        5
# 47        5
# 48        5
# 49        5
# 50        5
# 51        5
# 52        5
# 53        5
# 54        4
# 55        5
# 56        5
# 57        5
# 58        5
# 59        5
# 60        5
# 61        5
# 62        5
# 63        4
# 64        5
# 65        4
# 66        5
# 67        4
# 68        5
# 69        4
# 70        5
# ...

# %%
df.doors.value_counts(dropna=False)
# Out:
#  5     17481
#  2      5523
#  4      3001
#  3      2259
# NaN      359
#  6         5
#  1         2
# Name: doors, dtype: int64

# %%
df.doors.dtype
# Out:
# dtype('O')

# %%
df.doors.value_counts(dropna=False).index.nunique()
# Out:
# 6

# %%
df.doors = df.doors.astype("float")

# %%
df.doors.value_counts(dropna=False)
# Out:
# 5.0    17481
# 2.0     5523
# 4.0     3001
# 3.0     2259
# NaN      359
# 6.0        5
# 1.0        2
# Name: doors, dtype: int64

# %%
df.doors.dtype
# Out:
# dtype('float64')

# %%
show_null_perc(df.doors)
# Out:
# 1.25

# %%
# %%timeit
# [ str(i) for i in df.doors]

# %%
# %%timeit
# df.doors.apply(lambda x : str(x))

# %% [markdown]
# ## country_version

# %%
df.country_version.value_counts(dropna=False)
# Out:
# NaN                         11741
# [\n, Germany, \n]            7939
# [\n, Spain, \n]              6376
# [\n, Italy, \n]               679
# [\n, Belgium, \n]             641
# [\n, European Union, \n]      340
# [\n, Netherlands, \n]         306
# [\n, Austria, \n]             266
# [\n, France, \n]              101
# [\n, United States, \n]        57
# [\n, Czechia, \n]              47
# [\n, Poland, \n]               31
# [\n, Hungary, \n]              21
# [\n, Denmark, \n]              21
# [\n, Romania, \n]              12
# [\n, Japan, \n]                12
# [\n, Switzerland, \n]           9
# [\n, Luxembourg, \n]            9
# [\n, Sweden, \n]                6
# [\n, Slovenia, \n]              5
# [\n, Slovakia, \n]              4
# [\n, Croatia, \n]               3
# [\n, Bulgaria, \n]              1
# [\n, Malta, \n]                 1
# [\n, Canada, \n]                1
# [\n, Mexico, \n]                1
# Name: country_version, dtype: int64

# %%
df.country_version = pick_from_list(df.country_version)
df.country_version
# Out:
# 0           Spain
# 1           Spain
# 2           Spain
# 3           Spain
# 4           Spain
# 5         Germany
# 6           Spain
# 7           Spain
# 8              NaN
# 9           Spain
# 10             NaN
# 11          Spain
# 12          Spain
# 13             NaN
# 14          Spain
# 15        Germany
# 16             NaN
# 17          Spain
# 18          Spain
# 19          Spain
# 20          Spain
# 21          Spain
# 22          Spain
# 23             NaN
# 24          Spain
# 25          Spain
# 26          Spain
# 27             NaN
# 28          Spain
# 29             NaN
# 30             NaN
# 31             NaN
# 32          Spain
# 33          Spain
# 34          Spain
# 35          Spain
# 36          Spain
# 37          Spain
# 38             NaN
# 39             NaN
# 40          Spain
# 41             NaN
# 42             NaN
# 43          Spain
# 44          Spain
# 45          Spain
# 46          Spain
# 47          Spain
# 48          Spain
# ...

# %%
df.country_version.value_counts(dropna=False)
# Out:
# NaN                 11741
#  Germany             7939
#  Spain               6376
#  Italy                679
#  Belgium              641
#  European Union       340
#  Netherlands          306
#  Austria              266
#  France               101
#  United States         57
#  Czechia               47
#  Poland                31
#  Hungary               21
#  Denmark               21
#  Romania               12
#  Japan                 12
#  Switzerland            9
#  Luxembourg             9
#  Sweden                 6
#  Slovenia               5
#  Slovakia               4
#  Croatia                3
#  Bulgaria               1
#  Malta                  1
#  Canada                 1
#  Mexico                 1
# Name: country_version, dtype: int64

# %%
df.country_version.value_counts(dropna=False).shape
# Out:
# (26,)

# %%
df.country_version.dtype
# Out:
# dtype('O')

# %%
df[df["country_version"].isnull() & df["location"].notnull()][["country_version","location"]].index.shape
# Out:
# (11741,)

# %%
df[df["location"].isnull() & df["country_version"].notnull()][["country_version","location"]].index.shape
# Out:
# (0,)

# %% [markdown]
# We have location info and country_version not give any extra insight, drop it.

# %%
df.drop("country_version", axis=1, inplace=True)

# %% [markdown]
# ## offer_number

# %%
df.offer_number.value_counts(dropna=False)
# Out:
# NaN                                      5530
# [\n, 1, \n]                                28
# [\n, L-Vorlauf 2023, \n]                   10
# [\n, 30, \n]                                9
# [\n, 20, \n]                                9
# [\n, RE82542, \n]                           8
# [\n, 12, \n]                                8
# [\n, VR68485, \n]                           7
# [\n, SE63327, \n]                           7
# [\n, AB-99115, \n]                          7
# [\n, 10, \n]                                7
# [\n, GH09538, \n]                           7
# [\n, UC99209, \n]                           7
# [\n, HN48086, \n]                           7
# [\n, YA14051, \n]                           7
# [\n, 46, \n]                                7
# [\n, CH04939, \n]                           7
# [\n, GW56820, \n]                           7
# [\n, PC57566, \n]                           7
# [\n, MA43845, \n]                           7
# ...

# %%
df.offer_number = pick_from_list(df.offer_number)
df.offer_number
# Out:
# 0                          7468157
# 1                          7054863
# 2                          7410454
# 3                          7464503
# 4                          7127931
# 5                               NaN
# 6                          7201260
# 7                          7329555
# 8                          j107114
# 9                          7454322
# 10                         NK77971
# 11                         7209100
# 12                         6589713
# 13                         RZ47072
# 14                         6915941
# 15                         MB-2133
# 16                         j302025
# 17                         7436715
# 18                         7452684
# 19                         7391621
# 20                         7439910
# 21                         7398825
# 22                         7087471
# 23                           13031
# 24                         7443577
# 25                         7439238
# 26                         5880757
# ...

# %%
df.offer_number.value_counts(dropna=False)
# Out:
# NaN                              5530
#  1                                 28
#  L-Vorlauf 2023                    10
#  30                                 9
#  20                                 9
#  RE82542                            8
#  12                                 8
#  VR68485                            7
#  SE63327                            7
#  AB-99115                           7
#  10                                 7
#  GH09538                            7
#  UC99209                            7
#  HN48086                            7
#  YA14051                            7
#  46                                 7
#  CH04939                            7
#  GW56820                            7
#  PC57566                            7
#  MA43845                            7
#  15                                 7
#  28364                              7
#  CB35330                            7
#  WM12181                            7
#  39                                 6
# ...

# %%
df.offer_number.value_counts(dropna=False).shape
# Out:
# (20946,)

# %%
df.offer_number.dtype
# Out:
# dtype('O')

# %%
df.drop("offer_number", axis=1, inplace=True)

# %% [markdown]
# ## warranty

# %%
df.warranty.value_counts(dropna=False)
# Out:
# NaN                     12846
# [\n, 12 months, \n]      9545
# [\n, Yes, \n]            2319
# [\n, 24 months, \n]      1515
# [\n, 60 months, \n]       968
# [\n, 6 months, \n]        398
# [\n, 36 months, \n]       257
# [\n, 3 months, \n]        185
# [\n, 0 months, \n]        133
# [\n, 48 months, \n]        78
# [\n, 84 months, \n]        47
# [\n, 72 months, \n]        40
# [\n, 13 months, \n]        22
# [\n, 8 months, \n]         19
# [\n, 18 months, \n]        15
# [\n, 1 months, \n]         15
# [\n, 15 months, \n]        13
# [\n, 14 months, \n]        13
# [\n, 16 months, \n]        13
# [\n, 30 months, \n]        12
# [\n, 34 months, \n]        11
# [\n, 21 months, \n]        11
# [\n, 33 months, \n]        11
# [\n, 32 months, \n]         9
# [\n, 20 months, \n]         9
# [\n, 23 months, \n]         9
# [\n, 19 months, \n]         9
# [\n, 17 months, \n]         9
# [\n, 35 months, \n]         8
# [\n, 28 months, \n]         8
# [\n, 50 months, \n]         6
# ...

# %%
# pick_from_list(df.warranty)
# pick_from_list(df.warranty).replace("Yes", 1).value_counts(dropna=False)
# pick_from_list(df.warranty).astype("str").str.replace("Yes", "1").value_counts(dropna=False)

# %%
# len(re.findall("([0-9]+)", "[\n, Yes, \n]"))
# len(re.findall("([0-9]+)", "[\n, 4 months, \n]"))

# %%
df['warranty'].astype("str").apply(lambda x :re.findall("([0-9]+)", x)[0] if len(re.findall("([0-9]+)", x))>0 else  np.nan).value_counts(dropna=False)
# Out:
# NaN    15165
# 12      9545
# 24      1515
# 60       968
# 6        398
# 36       257
# 3        185
# 0        133
# 48        78
# 84        47
# 72        40
# 13        22
# 8         19
# 18        15
# 1         15
# 15        13
# 14        13
# 16        13
# 30        12
# 34        11
# 21        11
# 33        11
# 32         9
# 20         9
# 23         9
# 19         9
# 17         9
# 35         8
# 28         8
# 50         6
# 22         6
# 42         5
# 31         4
# 26         4
# 52         4
# 47         4
# 9          4
# 25         3
# 58         3
# 11         3
# 27         3
# 45         2
# 53         2
# 10         2
# 57         2
# 51         2
# 29         2
# 2          2
# 80         2
# 90         2
# 7          2
# 46         1
# 117        1
# 43         1
# 65         1
# 39         1
# 142        1
# 110        1
# 37         1
# 49         1
# 55         1
# 99         1
# 122        1
# 44         1
# 4          1
# ...

# %%
df['warranty'] = df['warranty'].astype("str").apply(lambda x :re.findall("([0-9]+)", x)[0] if len(re.findall("([0-9]+)", x))>0 else np.nan)

# %%
df['warranty'].value_counts(dropna=False).index
# Out:
# Index([  nan,  '12',  '24',  '60',   '6',  '36',   '3',   '0',  '48',  '84',
#         '72',  '13',   '8',  '18',   '1',  '15',  '14',  '16',  '30',  '34',
#         '21',  '33',  '32',  '20',  '23',  '19',  '17',  '35',  '28',  '50',
#         '22',  '42',  '31',  '26',  '52',  '47',   '9',  '25',  '58',  '11',
#         '27',  '45',  '53',  '10',  '57',  '51',  '29',   '2',  '80',  '90',
#          '7',  '46', '117',  '43',  '65',  '39', '142', '110',  '37',  '49',
#         '55',  '99', '122',  '44',   '4'],
#       dtype='object')

# %%
df['warranty'].value_counts(dropna=False).shape
# Out:
# (65,)

# %%
df.warranty = df.warranty.astype("float")
df.warranty.value_counts(dropna=False)
# Out:
# NaN      15165
# 12.0      9545
# 24.0      1515
# 60.0       968
# 6.0        398
# 36.0       257
# 3.0        185
# 0.0        133
# 48.0        78
# 84.0        47
# 72.0        40
# 13.0        22
# 8.0         19
# 18.0        15
# 1.0         15
# 15.0        13
# 14.0        13
# 16.0        13
# 30.0        12
# 34.0        11
# 21.0        11
# 33.0        11
# 32.0         9
# 20.0         9
# 23.0         9
# 19.0         9
# 17.0         9
# 35.0         8
# 28.0         8
# 50.0         6
# 22.0         6
# 42.0         5
# 31.0         4
# 26.0         4
# 52.0         4
# 47.0         4
# 9.0          4
# 25.0         3
# 58.0         3
# 11.0         3
# 27.0         3
# 45.0         2
# 53.0         2
# 10.0         2
# 57.0         2
# 51.0         2
# 29.0         2
# 2.0          2
# 80.0         2
# 90.0         2
# 7.0          2
# 46.0         1
# 117.0        1
# 43.0         1
# 65.0         1
# 39.0         1
# 142.0        1
# 110.0        1
# ...

# %%
df['warranty'].dtype
# Out:
# dtype('float64')

# %%
show_null_perc(df['warranty'])
# Out:
# 52.97

# %% [markdown]
# ## mileage

# %%
df.mileage.value_counts(dropna=False)
# Out:
# 10 km         586
# 1 km          172
# 50 km         133
# 100 km        119
# 5,000 km      118
# 5 km          114
# 20 km         101
# 15 km          91
# 100,000 km     79
# 3,000 km       77
# 90,000 km      72
# 8,000 km       66
# 2 km           66
# 160,000 km     64
# 6,000 km       64
# 60,000 km      62
# 10,000 km      60
# 150,000 km     59
# 140,000 km     59
# 15,000 km      58
# 1,500 km       54
# 80,000 km      54
# 120,000 km     53
# 130,000 km     53
# 85,000 km      52
# 1,000 km       51
# 110,000 km     50
# 200,000 km     50
# 9,900 km       49
# 50,000 km      48
# 65,000 km      48
# 170,000 km     48
# 9,500 km       48
# 75,000 km      47
# 89,000 km      47
# 125,000 km     45
# 55,000 km      45
# 70,000 km      44
# 2,500 km       43
# 4,500 km       43
# 25,000 km      42
# 30,000 km      42
# 20,000 km      41
# 500 km         41
# 9 km           41
# 45,000 km      40
# 3,500 km       40
# 190,000 km     40
# 99,000 km      40
# 180,000 km     39
# ...

# %%
# re.findall("([,0-9]+)", "100,000 km ") #test

# %%
df["mileage"] = df["mileage"].astype("str").apply(lambda x : float('%.2f'% float(re.findall("([,0-9]+)", x)[0].replace(",", ""))) if len(re.findall("([,0-9]+)", x))>0 else np.nan)

# %%
df["mileage"].value_counts(dropna = False)
# Out:
# 10.0        586
# 1.0         172
# 50.0        133
# 100.0       119
# 5000.0      118
# 5.0         114
# 20.0        101
# 15.0         91
# 100000.0     79
# 3000.0       77
# 90000.0      72
# 8000.0       66
# 2.0          66
# 160000.0     64
# 6000.0       64
# 60000.0      62
# 10000.0      60
# 150000.0     59
# 140000.0     59
# 15000.0      58
# 1500.0       54
# 80000.0      54
# 120000.0     53
# 130000.0     53
# 85000.0      52
# 1000.0       51
# 110000.0     50
# 200000.0     50
# 9900.0       49
# 50000.0      48
# 65000.0      48
# 170000.0     48
# 9500.0       48
# 75000.0      47
# 89000.0      47
# 125000.0     45
# 55000.0      45
# 70000.0      44
# 2500.0       43
# 4500.0       43
# 25000.0      42
# 30000.0      42
# 20000.0      41
# 500.0        41
# 9.0          41
# 45000.0      40
# 3500.0       40
# 190000.0     40
# 99000.0      40
# 180000.0     39
# 12.0         38
# 9000.0       38
# 35000.0      38
# 105000.0     38
# 2000.0       37
# ...

# %%
df["mileage"].value_counts(dropna = False).index.nunique()
# Out:
# 14183

# %%
df.mileage.dtype
# Out:
# dtype('float64')

# %%
show_null_perc(df.mileage)
# Out:
# 0.0

# %%
# df[df["mileage"].isna()]
df["mileage"].isna().sum()
# Out:
# 1

# %% [markdown]
# ## first_registration

# %%
df.first_registration.value_counts()
# Out:
# 08/2022    454
# 06/2022    428
# 05/2019    420
# 06/2019    418
# 07/2019    416
# 07/2022    412
# 06/2018    396
# 01/2019    390
# 05/2022    375
# 03/2019    372
# 05/2018    366
# 12/2021    364
# 03/2018    353
# 07/2018    349
# 04/2019    323
# 04/2022    317
# 06/2021    316
# 07/2020    315
# 09/2022    313
# 02/2019    309
# 01/2018    299
# 08/2018    294
# 08/2019    285
# 01/2022    282
# 03/2021    278
# 04/2018    275
# 05/2021    270
# 11/2018    267
# 03/2022    263
# 07/2021    261
# 02/2018    260
# 01/2020    251
# 04/2017    249
# 02/2020    248
# 03/2017    247
# 10/2021    238
# 10/2018    233
# 02/2022    232
# 05/2017    231
# 06/2020    230
# 06/2017    229
# 09/2021    225
# 12/2018    223
# 09/2020    218
# 11/2020    215
# 12/2020    214
# 01/2017    214
# 09/2019    208
# 11/2017    207
# 08/2020    207
# 07/2017    205
# 08/2021    197
# 09/2017    189
# 02/2021    188
# 10/2017    187
# 11/2021    185
# 10/2019    180
# 09/2018    177
# ...

# %%
df.first_registration.isna().sum()
# Out:
# 2

# %%
df.first_registration.dtype
# Out:
# dtype('O')

# %%
# re.findall("^{/}([0-9]+)","04/2018") #not work

# ("04/2018").split("/")[1]
# ("NaN").split("/")

# %%
df.first_registration = df.first_registration.astype(str).apply(lambda x : x.split("/")[1] if len(x.split("/"))>1 else np.nan).astype("float")

# %%
df.first_registration.value_counts(dropna=False)
# Out:
# 2019.0    3667
# 2018.0    3492
# 2022.0    3086
# 2021.0    2870
# 2020.0    2473
# 2017.0    2426
# 2016.0    1486
# 2015.0    1237
# 2014.0     936
# 2013.0     703
# 2012.0     655
# 2011.0     642
# 2010.0     559
# 2007.0     492
# 2008.0     441
# 2009.0     424
# 2006.0     395
# 2005.0     287
# 2004.0     247
# 2003.0     211
# 2001.0     191
# 2002.0     187
# 2000.0     160
# 1999.0     144
# 1998.0      91
# 1997.0      81
# 1994.0      80
# 1995.0      78
# 1996.0      71
# 1991.0      62
# 1992.0      60
# 1993.0      55
# 1990.0      54
# 1966.0      41
# 1967.0      34
# 1988.0      33
# 1965.0      32
# 1973.0      29
# 1972.0      29
# 1968.0      27
# 1987.0      26
# 1978.0      23
# 1986.0      22
# 1989.0      20
# 1970.0      19
# 1971.0      18
# 1985.0      18
# 1969.0      17
# 1979.0      17
# 1983.0      16
# 1975.0      14
# 1977.0      13
# 1964.0      11
# 1976.0      11
# 1982.0      11
# 1984.0      10
# 1981.0       9
# 1963.0       9
# ...

# %% [markdown]
# Note: There are cars with 2025 and 2202 regis years

# %%
df.first_registration.dtype
# Out:
# dtype('float64')

# %%
show_null_perc(df.first_registration)
# Out:
# 0.01

# %% [markdown]
# ## Create an age column
# Current year - first_registration

# %%
df["age"] = 2022 - df.first_registration
df["age"]
# Out:
# 0         6.0
# 1         0.0
# 2         2.0
# 3         2.0
# 4         7.0
# 5        17.0
# 6         4.0
# 7         3.0
# 8         3.0
# 9         4.0
# 10        7.0
# 11        6.0
# 12        9.0
# 13        2.0
# 14        6.0
# 15       12.0
# 16        1.0
# 17        3.0
# 18        2.0
# 19        6.0
# 20        4.0
# 21        2.0
# 22        1.0
# 23        3.0
# 24        1.0
# 25        4.0
# 26        1.0
# 27        8.0
# 28        8.0
# 29       17.0
# 30        2.0
# 31        2.0
# 32        1.0
# 33        6.0
# 34        5.0
# 35        2.0
# 36        4.0
# 37        3.0
# 38        3.0
# 39        8.0
# 40        3.0
# 41        1.0
# 42       11.0
# 43        4.0
# 44        3.0
# 45        1.0
# 46        3.0
# 47        6.0
# 48        4.0
# 49        2.0
# 50        9.0
# 51        6.0
# 52        3.0
# 53        4.0
# 54        3.0
# 55        4.0
# 56        4.0
# 57        2.0
# 58        2.0
# 59        2.0
# 60        2.0
# 61        4.0
# ...

# %%
df["age"].value_counts(dropna = False)
# Out:
#  3.0      3667
#  4.0      3492
#  0.0      3086
#  1.0      2870
#  2.0      2473
#  5.0      2426
#  6.0      1486
#  7.0      1237
#  8.0       936
#  9.0       703
#  10.0      655
#  11.0      642
#  12.0      559
#  15.0      492
#  14.0      441
#  13.0      424
#  16.0      395
#  17.0      287
#  18.0      247
#  19.0      211
#  21.0      191
#  20.0      187
#  22.0      160
#  23.0      144
#  24.0       91
#  25.0       81
#  28.0       80
#  27.0       78
#  26.0       71
#  31.0       62
#  30.0       60
#  29.0       55
#  32.0       54
#  56.0       41
#  55.0       34
#  34.0       33
#  57.0       32
#  49.0       29
#  50.0       29
#  54.0       27
#  35.0       26
#  44.0       23
#  36.0       22
#  33.0       20
#  52.0       19
#  51.0       18
#  37.0       18
#  53.0       17
#  43.0       17
#  39.0       16
#  47.0       14
#  45.0       13
#  58.0       11
#  46.0       11
#  40.0       11
#  38.0       10
#  41.0        9
#  59.0        9
# ...

# %%
df["age"].dtype
# Out:
# dtype('float64')

# %%
show_null_perc(df.age)
# Out:
# 0.01

# %% [markdown]
# Drop first reg and use age info

# %%
df.drop("first_registration", axis=1, inplace=True)

# %% [markdown]
# ## gearbox

# %%
df.gearbox.value_counts(dropna = False)
# Out:
# [\nManual\n]            17023
# [\nAutomatic\n]         11287
# NaN                       248
# [\nSemi-automatic\n]       72
# Name: gearbox, dtype: int64

# %%
df.gearbox = df.gearbox.str[0].str.strip("\n")

# %%
df.gearbox.value_counts(dropna = False)
# Out:
# Manual            17023
# Automatic         11287
# NaN                 248
# Semi-automatic       72
# Name: gearbox, dtype: int64

# %%
show_null_perc(df.gearbox)
# Out:
# 0.87

# %% [markdown]
# ## fuel_type

# %%
df.fuel_type.value_counts(dropna=False)
# Out:
# Gasoline                                                                                              8532
# Diesel                                                                                                5911
# Super 95                                                                                              3557
# Diesel (Particle filter)                                                                              2816
# Regular/Benzine 91                                                                                    2065
# NaN                                                                                                   1787
# Super E10 95                                                                                          1016
# Regular/Benzine 91 (Particle filter)                                                                   555
# Super 95 (Particle filter)                                                                             537
# ...

# %%
df.fuel_type.value_counts(dropna=False).index.shape
# Out:
# (47,)

# %% [markdown]
# Too many different fuel types(47 types)- combine them under common fileds
#
# Define a function to solve this

# %%
benzine = ["Gasoline","Super 95", "Regular/Benzine 91", "Super E10 95", "Regular/Benzine 91 (Particle filter)",
           "Super 95 (Particle filter)", "Super E10 95 (Particle filter)", "Regular/Benzine E10 91", "Gasoline (Particle filter)",
          "Super Plus 98", "Super Plus E10 98", "Super Plus E10 98 (Particle filter)", "Super Plus 98 (Particle filter)",
      
           "Regular/Benzine E10 91 (Particle filter)","Super 95 (Particle filter) / Super E10 95 / Ethanol","Ethanol"]
gas = ["Liquid petroleum gas (LPG)", "CNG", "LPG", "Domestic gas H", "Domestic gas L", "CNG (Particle filter)",
      "LPG (Particle filter)", "Hydrogen", "Biogas","Domestic gas L (Particle filter)","Liquid petroleum gas (LPG) (Particle filter)"]

gas_benzine = ["Liquid petroleum gas (LPG) (Particle filter) / Super 95 / Super E10 95",
               "Liquid petroleum gas (LPG) / Super 95 / Super Plus 98 / Super Plus E10 98 / Super E10 95",
               "Liquid petroleum gas (LPG) / Super 95 / Super E10 95", 
               "Liquid petroleum gas (LPG) / Super 95",
               "Liquid petroleum gas (LPG) / Super 95 / Super E10 95 / Super Plus 98",
               "Liquid petroleum gas (LPG) / Super 95 / Super Plus 98",
               "Liquid petroleum gas (LPG) / Super E10 95 / Super Plus E10 98 / Super Plus 98 / Super 95",
               "Liquid petroleum gas (LPG) / Super E10 95",
               "Super 95 / Super Plus 98 / Liquid petroleum gas (LPG)",
               "Domestic gas L / Super 95 / Domestic gas H",
               "Domestic gas H / Super E10 95 / Super Plus E10 98 / Super 95 / Super Plus 98 / Domestic gas L",
               "Liquid petroleum gas (LPG) / Super E10 95 / Regular/Benzine 91 / Super 95 / Super Plus 98 / Biogas",
               "Super 95 / Liquid petroleum gas (LPG)"]

diesel = ["Diesel", "Diesel (Particle filter)"]
                                                                   
electric = ["Electric", "Electric (Particle filter)"]

others = ["Others", "Others (Particle filter)"]

# %%
def fueltype(fuel):
    if fuel in benzine:
        return "benzine"
    elif fuel in gas:
        return "gas"
    elif fuel in gas_benzine:
        return "gas_benzine"
    elif fuel in diesel:
        return "diesel"
    elif fuel in electric:
        return "electric"
    elif fuel in others:
        return "others"
    else:
        return fuel

# %%
df.fuel_type = df.fuel_type.apply(fueltype)

# %%
df.fuel_type.value_counts(dropna=False)
# Out:
# benzine        17334
# diesel          8727
# NaN             1787
# gas              362
# others           213
# electric         188
# gas_benzine       19
# Name: fuel_type, dtype: int64

# %%
df.fuel_type.dtype
# Out:
# dtype('O')

# %%
show_null_perc(df.fuel_type)
# Out:
# 6.24

# %% [markdown]
# ## colour

# %%
df.colour.value_counts(dropna=False)
# Out:
# Black     6473
# Grey      5998
# White     5185
# Blue      3478
# Red       2242
# NaN       1724
# Silver    1622
# Green      450
# Brown      437
# Orange     288
# Beige      278
# Yellow     230
# Violet      98
# Bronze      65
# Gold        62
# Name: colour, dtype: int64

# %%
df.colour.value_counts(dropna=False).shape
# Out:
# (15,)

# %%
show_null_perc(df.colour)
# Out:
# 6.02

# %% [markdown]
# ## paint

# %%
df.paint.value_counts(dropna=False)
# Out:
# Metallic     14494
# NaN          14135
# Uni/basic        1
# Name: paint, dtype: int64

# %%
show_null_perc(df.paint)
# Out:
# 49.37

# %% [markdown]
# ## seller

# %%
df.seller.value_counts(dropna=False)
# Out:
# Dealer            26318
# Private seller     2312
# Name: seller, dtype: int64

# %%
show_null_perc(df.seller)
# Out:
# 0.0

# %% [markdown]
# ## seats

# %%
df.seats.value_counts(dropna=False)
# Out:
# [\n, 5, \n]     18308
# [\n, 4, \n]      5390
# NaN              3125
# [\n, 2, \n]      1186
# [\n, 7, \n]       488
# [\n, 8, \n]        43
# [\n, 9, \n]        35
# [\n, 3, \n]        25
# [\n, 6, \n]        12
# [\n, 0, \n]         9
# [\n, 1, \n]         7
# [\n, 17, \n]        2
# Name: seats, dtype: int64

# %%
df.seats = df.seats.str[0].str.strip("\n").str.replace(",","").astype("float")

# %%
df.seats.value_counts(dropna = False)
# Out:
# 5.0     18308
# 4.0      5390
# NaN      3125
# 2.0      1186
# 7.0       488
# 8.0        43
# 9.0        35
# 3.0        25
# 6.0        12
# 0.0         9
# 1.0         7
# 17.0        2
# Name: seats, dtype: int64

# %%
df.seats.value_counts(dropna = False).shape
# Out:
# (12,)

# %%
show_null_perc(df.seats)
# Out:
# 10.92

# %% [markdown]
# ## power
# Same information given in terms of kW and kW. Keep kW and turn it into float

# %%
df.power.value_counts(dropna=False)
# Out:
# [\n110 kW (150 hp)\n]      1992
# [\n96 kW (131 hp)\n]       1356
# [\n88 kW (120 hp)\n]       1182
# [\n81 kW (110 hp)\n]       1166
# [\n66 kW (90 hp)\n]        1110
# [\n103 kW (140 hp)\n]      1033
# [\n85 kW (116 hp)\n]       1002
# [\n74 kW (101 hp)\n]        892
# [\n140 kW (190 hp)\n]       787
# [\n51 kW (69 hp)\n]         701
# [\n70 kW (95 hp)\n]         685
# [\n100 kW (136 hp)\n]       681
# NaN                         572
# [\n55 kW (75 hp)\n]         515
# [\n92 kW (125 hp)\n]        477
# [\n147 kW (200 hp)\n]       458
# [\n125 kW (170 hp)\n]       422
# [\n120 kW (163 hp)\n]       418
# [\n80 kW (109 hp)\n]        349
# [\n132 kW (179 hp)\n]       339
# [\n90 kW (122 hp)\n]        318
# [\n135 kW (184 hp)\n]       296
# [\n173 kW (235 hp)\n]       249
# [\n118 kW (160 hp)\n]       247
# [\n115 kW (156 hp)\n]       246
# [\n130 kW (177 hp)\n]       241
# [\n84 kW (114 hp)\n]        240
# [\n77 kW (105 hp)\n]        236
# [\n221 kW (300 hp)\n]       234
# ...

# %%
# len(re.findall("\\n([0-9]+)","[\n82 kW (111 hp)\n]"))
# re.findall("([0-9]+)","['\n215 kW (292 hp)\n']")[0]
# len(re.findall("([0-9]+)","NaN"))[0]
# re.findall("([,0-9]+)","['\n215,234 kW (292 hp)\n']")[0]
# re.findall("([,0-9]+)","['\n215 ,7654kW (292,345 hp)\n']")[0]

# %%
# Alternativel use str extract 
# df.power.astype("str").str.split(" ").str[2].str.extract('(\d{1,4})').astype("float").min()
# df.power.astype("str").str.split(" ").str[0].str.extract('(\d{1,4})').astype("float").max()
# df.power.astype("str").str.split(" ").str[0].str.extract('(\d{1,4})')

# %%
# Use regex
# Use [0] for kW or [1] for hp 
# df.power.astype("str").apply(lambda x : re.findall("([,0-9]+)",x)[1] if len(re.findall("([,0-9]+)",x))>0 else np.nan).str.replace(",","").astype("float").max()
# df.power.astype("str").apply(lambda x : re.findall("([,0-9]+)",x)[0] if len(re.findall("([,0-9]+)",x))>0 else np.nan).str.replace(",","").astype("float").value_counts(dropna = False)

# %%
df.power = df.power.astype("str").apply(lambda x : re.findall("([,0-9]+)",x)[0] if len(re.findall("([,0-9]+)",x))>0 else np.nan).str.replace(",","").astype("float")

# %%
df.power.value_counts(dropna=False)
# Out:
# 110.0    1992
# 96.0     1356
# 88.0     1182
# 81.0     1166
# 66.0     1110
# 103.0    1033
# 85.0     1002
# 74.0      892
# 140.0     787
# 51.0      701
# 70.0      685
# 100.0     681
# NaN       572
# 55.0      515
# 92.0      477
# 147.0     458
# 125.0     422
# 120.0     418
# 80.0      349
# 132.0     339
# 90.0      318
# 135.0     296
# 173.0     249
# 118.0     247
# 115.0     246
# 130.0     241
# 84.0      240
# 77.0      236
# 221.0     234
# 150.0     232
# 206.0     224
# 67.0      213
# 82.0      204
# 63.0      200
# 145.0     199
# 97.0      185
# 53.0      176
# 104.0     163
# 288.0     155
# 59.0      149
# 143.0     143
# 73.0      139
# 184.0     138
# 121.0     134
# 44.0      133
# 60.0      133
# 180.0     130
# 165.0     130
# 75.0      128
# 68.0      127
# 202.0     126
# 107.0     124
# 54.0      120
# 190.0     119
# 331.0     118
# 241.0     117
# 162.0     115
# 52.0      112
# 99.0      111
# 228.0     105
# 225.0     104
# 169.0     103
# ...

# %%
df.power.value_counts(dropna=False).shape
# Out:
# (352,)

# %%
df.power.dtype
# Out:
# dtype('float64')

# %%
show_null_perc(df.power)
# Out:
# 2.0

# %% [markdown]
# ## engine_size

# %%
df.engine_size.value_counts(dropna=False)
# Out:
# [\n1,598 cc\n]     2099
# [\n999 cc\n]       2068
# [\n1,969 cc\n]     1929
# NaN                1403
# [\n1,461 cc\n]     1110
# [\n1,998 cc\n]     1000
# [\n998 cc\n]        925
# [\n1,199 cc\n]      867
# [\n1,498 cc\n]      782
# [\n1,997 cc\n]      665
# [\n1,968 cc\n]      625
# [\n1,984 cc\n]      580
# [\n1,332 cc\n]      510
# [\n1,798 cc\n]      473
# [\n1,560 cc\n]      472
# [\n898 cc\n]        405
# [\n1,499 cc\n]      397
# [\n1,197 cc\n]      382
# [\n1,242 cc\n]      373
# [\n1,995 cc\n]      352
# [\n1,991 cc\n]      351
# [\n1,368 cc\n]      348
# [\n1,248 cc\n]      322
# [\n2,435 cc\n]      302
# [\n1,600 cc\n]      252
# [\n2,143 cc\n]      242
# [\n1,364 cc\n]      226
# [\n1,500 cc\n]      210
# [\n5,038 cc\n]      204
# [\n3,982 cc\n]      203
# [\n1,950 cc\n]      202
# [\n1,591 cc\n]      201
# [\n1,956 cc\n]      195
# [\n2,000 cc\n]      191
# [\n3,498 cc\n]      175
# [\n1,395 cc\n]      174
# [\n1,987 cc\n]      159
# [\n1,149 cc\n]      157
# ...

# %%
# re.findall("([,0-9]+)","[\n2,402 cc\n]")
# re.findall("([,0-9]+)","[\n498 cc\n]")

# %%
df.engine_size = df.engine_size.astype("str").apply(lambda x : re.findall("([,0-9]+)",x)[0] if len(re.findall("([,0-9]+)",x))>0 else np.nan).str.replace(",","").astype("float")

# %%
df.engine_size.value_counts(dropna=False)
# Out:
# 1598.0     2099
# 999.0      2068
# 1969.0     1929
# NaN        1403
# 1461.0     1110
# 1998.0     1000
# 998.0       925
# 1199.0      867
# 1498.0      782
# 1997.0      665
# 1968.0      625
# 1984.0      580
# 1332.0      510
# 1798.0      473
# 1560.0      472
# 898.0       405
# 1499.0      397
# 1197.0      382
# 1242.0      373
# 1995.0      352
# 1991.0      351
# 1368.0      348
# 1248.0      322
# 2435.0      302
# 1600.0      252
# 2143.0      242
# 1364.0      226
# 1500.0      210
# 5038.0      204
# 3982.0      203
# 1950.0      202
# 1591.0      201
# 1956.0      195
# 2000.0      191
# 3498.0      175
# 1395.0      174
# 1987.0      159
# 1149.0      157
# 1796.0      156
# 3696.0      154
# 1200.0      153
# 1490.0      152
# 1198.0      149
# 1497.0      149
# 2400.0      148
# 1999.0      145
# 2996.0      145
# 1398.0      143
# 1794.0      138
# 1496.0      137
# 1618.0      128
# 1482.0      127
# 1582.0      125
# 0.0         117
# 2925.0      117
# ...

# %%
df.engine_size.value_counts(dropna=False).shape
# Out:
# (468,)

# %%
df.engine_size.dtype
# Out:
# dtype('float64')

# %%
show_null_perc(df.engine_size)
# Out:
# 4.9

# %% [markdown]
# ## gears

# %%
#type(df.gears[3])
df.gears.value_counts(dropna=False)
# Out:
# NaN         9676
# [\n6\n]     8412
# [\n5\n]     5335
# [\n7\n]     1738
# [\n8\n]     1690
# [\n1\n]      712
# [\n9\n]      642
# [\n4\n]      256
# [\n10\n]     112
# [\n0\n]       31
# [\n3\n]       24
# [\n2\n]        2
# Name: gears, dtype: int64

# %%
#test first
#df.gears.astype("str").apply(lambda x : re.findall("[0-9]+",x)[0] if len(re.findall("[0-9]+",x))>0 else np.nan).astype(float).value_counts(dropna=False)

# %%
df.gears = df.gears.astype("str").apply(lambda x : re.findall("[0-9]+",x)[0] if len(re.findall("[0-9]+",x))>0 else np.nan).astype(float)

# %%
df.gears.value_counts(dropna=False)
# Out:
# NaN     9676
# 6.0     8412
# 5.0     5335
# 7.0     1738
# 8.0     1690
# 1.0      712
# 9.0      642
# 4.0      256
# 10.0     112
# 0.0       31
# 3.0       24
# 2.0        2
# Name: gears, dtype: int64

# %%
df.gears.value_counts(dropna=False).shape
# Out:
# (12,)

# %%
df.gears.dtype
# Out:
# dtype('float64')

# %%
show_null_perc(df.gears)
# Out:
# 33.8

# %% [markdown]
# ## co_emissions
# $CO_2$ emmision is given in g/km (combined)

# %%
df.co_emissions.value_counts(dropna=False)
# Out:
# NaN                    10036
# 0 g/km (comb.)          1038
# 119 g/km (comb.)         393
# 124 g/km (comb.)         340
# 129 g/km (comb.)         319
# 114 g/km (comb.)         313
# 99 g/km (comb.)          312
# 115 g/km (comb.)         304
# 139 g/km (comb.)         298
# 109 g/km (comb.)         265
# 108 g/km (comb.)         262
# 125 g/km (comb.)         255
# 149 g/km (comb.)         255
# 123 g/km (comb.)         230
# 138 g/km (comb.)         230
# 130 g/km (comb.)         227
# 120 g/km (comb.)         218
# 117 g/km (comb.)         214
# 110 g/km (comb.)         213
# 127 g/km (comb.)         211
# 126 g/km (comb.)         204
# 111 g/km (comb.)         204
# 104 g/km (comb.)         197
# 112 g/km (comb.)         186
# 95 g/km (comb.)          183
# 107 g/km (comb.)         179
# 135 g/km (comb.)         178
# 116 g/km (comb.)         175
# 154 g/km (comb.)         173
# 134 g/km (comb.)         171
# 145 g/km (comb.)         170
# 122 g/km (comb.)         169
# ...

# %%
# df.co_emissions.astype(str).apply(lambda x: re.findall("[,0-9]+",x)[0] if len(re.findall("[,0-9]+",x))>0 else np.nan).str.replace(",","").astype(float).value_counts(dropna=False)

# %%
df.co_emissions = df.co_emissions.astype(str).apply(lambda x: re.findall("[,0-9]+",x)[0] if len(re.findall("[,0-9]+",x))>0 else np.nan).str.replace(",","").astype(float)

# %%
df.co_emissions.value_counts(dropna=False)
# Out:
# NaN        10036
# 0.0         1040
# 119.0        393
# 124.0        340
# 129.0        319
# 114.0        313
# 99.0         312
# 115.0        304
# 139.0        299
# 109.0        265
# 108.0        262
# 149.0        255
# 125.0        255
# 138.0        230
# 130.0        230
# 123.0        230
# 120.0        218
# 117.0        214
# 110.0        213
# 127.0        211
# 111.0        204
# 126.0        204
# 104.0        197
# 112.0        186
# 95.0         184
# 107.0        179
# 135.0        178
# 116.0        175
# 154.0        173
# 134.0        171
# 145.0        170
# 122.0        170
# 178.0        165
# 133.0        165
# 113.0        161
# 128.0        159
# 106.0        158
# 121.0        157
# 103.0        157
# 131.0        153
# 93.0         147
# 98.0         144
# 105.0        142
# 156.0        141
# 148.0        139
# 140.0        139
# 118.0        139
# 155.0        137
# 88.0         136
# 159.0        136
# 136.0        135
# 144.0        135
# ...

# %%
df.co_emissions.value_counts(dropna=False).shape
# Out:
# (334,)

# %%
df.co_emissions.dtype
# Out:
# dtype('float64')

# %%
show_null_perc(df.co_emissions)
# Out:
# 35.05

# %% [markdown]
# ## manufacturer_colour

# %%
df.manufacturer_colour.value_counts(dropna=False)
# Out:
# NaN                               6843
# Blanco                            1235
# Gris                               671
# Azul                               552
# Negro                              546
# Rojo                               381
# Grijs metallic                     375
# Zwart metallic                     295
# Zwart                              232
# Schwarz                            228
# Wit                                223
# Grijs                              215
# Bianco                             170
# Blauw metallic                     156
# Obsidianschwarz                    136
# Grau                               129
# Nero                               129
# -                                  120
# Gris Plata                         119
# Onyx Schwarz                       111
# Schwarz-Magic Perleffekt           109
# Grigio                             108
# Onyx black / metallic              100
# Blauw                               98
# ...

# %%
df.manufacturer_colour = df.manufacturer_colour.replace({"-":np.nan})

# %%
df.manufacturer_colour.value_counts(dropna=False)
# Out:
# NaN                               6963
# Blanco                            1235
# Gris                               671
# Azul                               552
# Negro                              546
# Rojo                               381
# Grijs metallic                     375
# Zwart metallic                     295
# Zwart                              232
# Schwarz                            228
# Wit                                223
# Grijs                              215
# Bianco                             170
# Blauw metallic                     156
# Obsidianschwarz                    136
# Grau                               129
# Nero                               129
# Gris Plata                         119
# Onyx Schwarz                       111
# Schwarz-Magic Perleffekt           109
# Grigio                             108
# Onyx black / metallic              100
# Blauw                               98
# BLANCO                              94
# ...

# %%
#check if there is any list type

for i in df.manufacturer_colour:
    if type(i)==list:
        print(i)

# for y in df.manufacturer_colour:
#     if "[" in str(y):
#         print(type(y))

# %%
df.manufacturer_colour.value_counts(dropna=False).shape
# Out:
# (4963,)

# %%
df.colour.value_counts(dropna=False).shape
# Out:
# (15,)

# %% [markdown]
# Compare colour and manufacurer colour by cheching nulls

# %%
show_null_perc(df.colour)
# Out:
# 6.02

# %%
show_null_perc(df.manufacturer_colour)
# Out:
# 24.32

# %%
df[df["colour"].isnull() & df["manufacturer_colour"].notnull()][["colour","manufacturer_colour"]].index.shape
#we can use manufacturer colour values to fill colour nan values
# Out:
# (1481,)

# %%
df[df["manufacturer_colour"].isnull() & df["colour"].notnull()][["colour","manufacturer_colour"]].index.shape
# Out:
# (6720,)

# %%
#drop it
df.drop("manufacturer_colour",axis=1,inplace=True)

# %% [markdown]
# ## drivetrain

# %%
df.drivetrain.value_counts(dropna=False)
# Out:
# [\n, Front, \n]    12066
# NaN                11737
# [\n, 4WD, \n]       3252
# [\n, Rear, \n]      1575
# Name: drivetrain, dtype: int64

# %%
df.drivetrain = pick_from_list(df.drivetrain)

# %%
df.drivetrain.value_counts(dropna=False)
# Out:
#  Front     12066
# NaN        11737
#  4WD        3252
#  Rear       1575
# Name: drivetrain, dtype: int64

# %%
show_null_perc(df.drivetrain)
# Out:
# 41.0

# %% [markdown]
# ## cylinders

# %%
df.cylinders.value_counts(dropna=False)
# Out:
# [\n4\n]     13068
# NaN          9778
# [\n3\n]      3258
# [\n6\n]      1013
# [\n5\n]       799
# [\n8\n]       539
# [\n2\n]       103
# [\n0\n]        35
# [\n1\n]        21
# [\n12\n]        8
# [\n7\n]         6
# [\n26\n]        1
# [\n16\n]        1
# Name: cylinders, dtype: int64

# %%
df.cylinders = df.cylinders.astype(str).apply(lambda x: re.findall("[0-9]+",x)[0] if len(re.findall("[0-9]+",x))>0 else np.nan).astype(float)

# %%
df.cylinders.value_counts(dropna=False)
# Out:
# 4.0     13068
# NaN      9778
# 3.0      3258
# 6.0      1013
# 5.0       799
# 8.0       539
# 2.0       103
# 0.0        35
# 1.0        21
# 12.0        8
# 7.0         6
# 26.0        1
# 16.0        1
# Name: cylinders, dtype: int64

# %%
df.cylinders.value_counts(dropna=False).shape
# Out:
# (13,)

# %%
df.cylinders.dtype
# Out:
# dtype('float64')

# %%
show_null_perc(df.cylinders)
# Out:
# 34.15

# %%
# testll = [[2],[3]]
# testll[3]

# %% [markdown]
# ## fuel_consumption
# Fuel consumption is given in lt over 100 km. It is given as comb, city, or country.

# %%
df.fuel_consumption.value_counts(dropna=False)
# Out:
# NaN                                                                              5245
# [[0 l/100 km (comb.)]]                                                            330
# [[0 l/100 km (comb.)], [0 l/100 km (city)], [0 l/100 km (country)]]               306
# [[3.4 l/100 km (comb.)], [3.7 l/100 km (city)], [3.2 l/100 km (country)]]         170
# [[4 l/100 km (comb.)]]                                                            149
# [[3.9 l/100 km (comb.)]]                                                          133
# [[3.8 l/100 km (comb.)], [4.2 l/100 km (city)], [3.6 l/100 km (country)]]         110
# [[5.1 l/100 km (comb.)], [6.4 l/100 km (city)], [4.3 l/100 km (country)]]         105
# [[5.4 l/100 km (comb.)], [6.2 l/100 km (city)], [5 l/100 km (country)]]           101
# [[3.7 l/100 km (comb.)], [4.4 l/100 km (city)], [3.3 l/100 km (country)]]         101
# [[4.5 l/100 km (comb.)]]                                                           97
# ...

# %%
# df.fuel_consumption.str[0].value_counts(dropna=False)

# %%
#use string to test this
#df.fuel_consumption.str[0].astype(str).str.replace("[","").str.replace("'","").str.extract('(\S+)').astype("float").value_counts(dropna= False)

# %% [markdown]
# Define some functions to extract each section of consumption

# %%
def combined(x):
    if type(x) == list and len(x) >= 1:
        if x[0] != []:
            return x[0][0]
        else:
            return None
    else:
        return None

# %%
def city(x):
    if type(x) == list and len(x) >= 2:
        if x[1] != []:
            return x[1][0]
        else:
            return None
    else:
        return None

# %%
def country(x):
    if type(x) == list and len(x) >= 3:
        if x[2] != []:
            return x[2][0]
        else:
            return None
    else:
        return None

# %%
# type(df.fuel_consumption.apply(combined).str.extract('(\S+)').astype("float")[0][0]) #test

df["fuel_comb_cons"] = df.fuel_consumption.apply(combined).str.extract('(\S+)').astype("float")

# %%
df.fuel_comb_cons.value_counts(dropna=False)
# Out:
# NaN     5245
# 5.0      831
# 4.9      812
# 4.5      690
# 0.0      652
# 5.1      647
# 4.7      618
# 5.4      609
# 4.8      609
# 5.6      594
# 4.3      564
# 5.3      558
# 5.2      552
# 4.6      550
# 4.2      539
# 4.1      518
# 3.8      516
# 5.7      504
# 5.5      503
# 5.9      498
# 4.0      484
# 4.4      442
# 6.4      438
# 6.0      430
# 6.3      414
# 5.8      399
# 3.7      360
# 3.9      353
# 3.6      327
# 7.0      312
# 3.4      296
# 6.5      292
# 6.1      282
# 6.2      278
# 6.6      274
# 6.9      270
# 7.4      265
# 7.1      253
# 6.7      251
# 6.8      226
# 7.3      220
# 7.2      202
# 8.4      194
# 8.0      194
# 7.6      181
# 3.5      180
# 8.2      166
# 7.7      165
# 7.8      165
# 7.5      156
# 12.0     110
# 3.3      109
# 9.0      107
# 9.2      103
# 12.5     102
# 8.6       95
# 9.8       93
# 8.9       92
# 8.3       88
# 3.0       84
# 7.9       83
# 9.6       79
# 8.7       79
# 1.7       77
# 9.5       77
# 1.5       73
# ...

# %%
df.fuel_comb_cons.value_counts(dropna=False).index.shape
# Out:
# (162,)

# %%
show_null_perc(df.fuel_comb_cons)
# Out:
# 18.32

# %%
df["fuel_city_cons"] = df.fuel_consumption.apply(city).str.extract('(\S+)').astype("float")

# %%
df.fuel_city_cons.value_counts(dropna=False)
# Out:
# NaN     8473
# 5.8      495
# 6.4      485
# 5.3      483
# 5.7      464
# 6.3      433
# 6.5      426
# 6.2      423
# 5.9      420
# 5.5      412
# 6.0      408
# 6.1      401
# 0.0      397
# 5.6      384
# 6.6      374
# 5.2      374
# 5.0      348
# 4.4      327
# 6.7      321
# 5.4      321
# 4.2      311
# 6.8      308
# 7.0      301
# 7.8      293
# 7.6      278
# 4.3      277
# 5.1      272
# 7.9      261
# 3.7      259
# 4.7      245
# 8.5      244
# 7.5      236
# 4.9      232
# 4.6      232
# 7.1      228
# 7.2      208
# 7.3      207
# 9.3      206
# 4.5      205
# 4.8      205
# 8.2      205
# 6.9      204
# 10.1     190
# 8.9      189
# 8.0      186
# 7.4      186
# 8.6      182
# 8.1      180
# 9.1      177
# 8.7      175
# 8.8      172
# 7.7      171
# 9.0      168
# 4.1      167
# 8.4      146
# 3.8      129
# 9.6      127
# 11.5     127
# 10.4     126
# 8.3      122
# 4.0      120
# 9.5      119
# 10.2     117
# 10.0     115
# 11.2     112
# 10.9     106
# ...

# %%
df.fuel_city_cons.value_counts(dropna=False).index.shape
# Out:
# (196,)

# %%
show_null_perc(df.fuel_city_cons)
# Out:
# 29.59

# %%
df["fuel_country_cons"] = df.fuel_consumption.apply(country).str.extract('(\S+)').astype("float")

# %%
df.fuel_country_cons.value_counts(dropna=False)
# Out:
# NaN     8530
# 4.3      884
# 4.0      804
# 4.2      750
# 4.7      730
# 5.0      725
# 3.6      679
# 4.6      668
# 4.9      663
# 3.8      660
# 4.5      659
# 3.9      640
# 4.1      632
# 5.1      598
# 4.4      587
# 3.7      520
# 5.7      474
# 4.8      460
# 5.4      445
# 5.2      443
# 5.3      413
# 5.6      394
# 5.5      383
# 0.0      379
# 5.8      376
# 3.4      341
# 3.2      334
# 3.3      327
# 3.5      304
# 5.9      301
# 6.5      289
# 6.2      261
# 6.0      242
# 6.7      239
# 6.1      229
# 7.0      205
# 6.4      202
# 6.3      199
# 3.0      163
# 6.9      150
# 6.8      139
# 3.1      136
# 7.4      113
# 8.7      108
# 6.6      108
# 7.8      105
# 8.1       98
# 7.6       98
# 7.1       98
# 7.7       94
# 9.1       84
# 7.3       78
# 8.3       77
# 7.2       77
# 8.0       77
# 8.5       75
# 8.2       69
# 8.8       65
# 2.9       62
# 7.9       62
# 9.3       53
# 9.6       44
# 7.5       42
# 8.9       36
# 9.0       34
# 8.4       33
# ...

# %%
df.fuel_country_cons.value_counts(dropna=False).index.shape
# Out:
# (115,)

# %%
show_null_perc(df.fuel_country_cons)
# Out:
# 29.79

# %% [markdown]
# Drop consupmtion

# %%
df.drop("fuel_consumption", axis=1, inplace=True)

# %% [markdown]
# ## comfort_convenience

# %%
df.comfort_convenience
# Out:
# 0                                                      NaN
# 1                                                      NaN
# 2                                                      NaN
# 3        [Air conditioning, Automatic climate control, ...
# 4        [Air conditioning, Electrical side mirrors, Mu...
# 5        [Air conditioning, Armrest, Automatic climate ...
# 6                                                      NaN
# 7        [Air conditioning, Automatic climate control, ...
# 8        [Multi-function steering wheel, Navigation sys...
# 9        [Air conditioning, Automatic climate control, ...
# 10       [Air conditioning, Armrest, Electrical side mi...
# 11       [Air conditioning, Electrical side mirrors, Po...
# 12       [Air conditioning, Electrical side mirrors, Mu...
# 13       [Air conditioning, Armrest, Automatic climate ...
# 14       [Air conditioning, Electrical side mirrors, Mu...
# 15       [Air conditioning, Armrest, Electrical side mi...
# ...

# %%
df.comfort_convenience.value_counts(dropna=False)
# Out:
# NaN                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               3197
# ...

# %%
df.comfort_convenience.value_counts(dropna=False).index.shape
# Out:
# (14439,)

# %% [markdown]
# Too many features keep them as it is by taking them out of list and later by comparing with the price group them into classes

# %%
df.comfort_convenience = [",".join(i) if type(i) == list else i for i in df.comfort_convenience]

# %%
df.comfort_convenience.value_counts(dropna=False)
# Out:
# NaN                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             3197
# ...

# %%
df.comfort_convenience.dtype
# Out:
# dtype('O')

# %%
type(df.comfort_convenience[10])
# Out:
# str

# %%
df.comfort_convenience.value_counts(dropna=False).index.shape
# Out:
# (14439,)

# %%
show_null_perc(df.comfort_convenience)
# Out:
# 11.17

# %% [markdown]
# ## entertainment_media

# %%
df.entertainment_media
# Out:
# 0                                                      NaN
# 1                                                      NaN
# 2                                                      NaN
# 3                                                    [USB]
# 4                         [Bluetooth, CD player, MP3, USB]
# 5                    [CD player, On-board computer, Radio]
# 6                                                      NaN
# 7                                                    [USB]
# 8                                                      NaN
# 9                                                      NaN
# 10       [Bluetooth, CD player, MP3, On-board computer,...
# 11                                                     NaN
# 12                        [Bluetooth, CD player, MP3, USB]
# 13       [Bluetooth, Digital cockpit, Hands-free equipm...
# 14                        [Bluetooth, CD player, MP3, USB]
# 15       [CD player, Hands-free equipment, On-board com...
# ...

# %%
df.entertainment_media.value_counts(dropna=False)
# Out:
# NaN                                                                                                                                                                                                                                 4986
# [Bluetooth, USB]                                                                                                                                                                                                                     753
# [Bluetooth]                                                                                                                                                                                                                          665
# [On-board computer]                                                                                                                                                                                                                  662
# ...

# %%
df.entertainment_media.value_counts(dropna=False).index.shape
# Out:
# (1945,)

# %%
show_null_perc(df.entertainment_media)
# Out:
# 17.42

# %% [markdown]
# Too many features keep them as it is by taking them out of list and later by comparing with the price group them into classes

# %%
df.entertainment_media = [",".join(i) if type(i) == list else i for i in df.entertainment_media]

# %%
df.entertainment_media.dtype
# Out:
# dtype('O')

# %%
type(df.entertainment_media[99])
# Out:
# str

# %% [markdown]
# ## safety_security

# %%
df.safety_security
# Out:
# 0                                                      NaN
# 1                                                      NaN
# 2                                                      NaN
# 3        [ABS, Central door lock, Driver-side airbag, E...
# 4        [ABS, Central door lock, Driver-side airbag, E...
# 5        [ABS, Bi-Xenon headlights, Central door lock, ...
# 6                                                      NaN
# 7        [ABS, Central door lock, Driver-side airbag, E...
# 8                              [Emergency brake assistant]
# 9        [ABS, Central door lock, Driver-side airbag, E...
# 10       [ABS, Alarm system, Central door lock, Central...
# 11       [ABS, Central door lock, Driver-side airbag, I...
# 12       [ABS, Central door lock, Driver-side airbag, E...
# 13       [ABS, Alarm system, Central door lock, Central...
# 14       [ABS, Central door lock, Driver-side airbag, E...
# 15       [ABS, Central door lock, Driver-side airbag, E...
# ...

# %%
df.safety_security.value_counts(dropna=False)
# Out:
# NaN                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         3215
# ...

# %%
show_null_perc(df.safety_security)
# Out:
# 11.23

# %%
df.safety_security.value_counts(dropna=False).index.shape
# Out:
# (12550,)

# %% [markdown]
# Too many features keep them as it is by taking them out of list and later by comparing with the price group them into classes

# %%
df.safety_security = [",".join(i) if type(i) == list else i for i in df.safety_security]

# %%
df.safety_security.dtype
# Out:
# dtype('O')

# %%
#test
type(df.safety_security[39])
# Out:
# str

# %%
df.safety_security.value_counts(dropna=False)
# Out:
# NaN                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       3215
# ...

# %% [markdown]
# ## extras

# %%
df.extras
# Out:
# 0                                                      NaN
# 1                                                      NaN
# 2                                                      NaN
# 3                                            [Sport seats]
# 4                                                      NaN
# 5        [Alloy wheels (17"), Catalytic Converter, Emer...
# 6                                                      NaN
# 7                                                      NaN
# 8                                          [Sport package]
# 9                                           [Alloy wheels]
# 10                                 [Alloy wheels, Spoiler]
# 11                             [Alloy wheels, Sport seats]
# 12           [Alloy wheels, Sport seats, Sport suspension]
# 13       [Alloy wheels, Automatically dimming interior ...
# 14                                                     NaN
# 15       [Alloy wheels, Automatically dimming interior ...
# ...

# %%
df.extras.value_counts(dropna=False)
# Out:
# NaN                                                                                                                                                                                                                                                                       5150
# [Alloy wheels]                                                                                                                                                                                                                                                            3408
# [Alloy wheels, Roof rack]                                                                                                                                                                                                                                                  380
# ...

# %%
df.extras.value_counts(dropna=False).index.shape
# Out:
# (9361,)

# %%
show_null_perc(df.extras)
# Out:
# 17.99

# %% [markdown]
# Too many features keep them as it is by taking them out of list and later by comparing with the price group them into classes

# %%
df.extras = [",".join(i) if type(i) == list else i for i in df.extras]

# %%
df.extras.dtype
# Out:
# dtype('O')

# %%
type(df.extras[34])
# Out:
# str

# %%
df.extras.value_counts(dropna=False)
# Out:
# NaN                                                                                                                                                                                                                                                                     5150
# Alloy wheels                                                                                                                                                                                                                                                            3408
# Alloy wheels, Roof rack                                                                                                                                                                                                                                                  380
# ...

# %% [markdown]
# ## empty_weight

# %%
df.empty_weight.value_counts(dropna=False)
# Out:
# NaN                10872
# [\n1,395 kg\n]       233
# [\n1,055 kg\n]       224
# [\n1,423 kg\n]       216
# [\n1,165 kg\n]       200
# [\n1,320 kg\n]       192
# [\n1,280 kg\n]       179
# [\n1,090 kg\n]       129
# [\n1,370 kg\n]       120
# [\n1,615 kg\n]       113
# [\n1,472 kg\n]       112
# [\n1,310 kg\n]       112
# [\n1,315 kg\n]       109
# [\n1,350 kg\n]       108
# [\n1,701 kg\n]       107
# [\n1,050 kg\n]       104
# [\n905 kg\n]          97
# [\n1,390 kg\n]        94
# [\n1,485 kg\n]        92
# [\n1,735 kg\n]        90
# [\n1,295 kg\n]        88
# [\n1,355 kg\n]        86
# [\n1,275 kg\n]        84
# [\n1,345 kg\n]        83
# [\n1,430 kg\n]        83
# [\n1,425 kg\n]        81
# [\n1,040 kg\n]        80
# [\n1,365 kg\n]        79
# [\n1,245 kg\n]        79
# [\n1,500 kg\n]        78
# [\n1,135 kg\n]        77
# [\n980 kg\n]          76
# [\n1,505 kg\n]        75
# [\n1,255 kg\n]        73
# [\n975 kg\n]          70
# [\n1,305 kg\n]        70
# [\n1,015 kg\n]        69
# ...

# %%
#df.empty_weight.astype(str).apply(lambda x : re.findall("[,0-9]+",x)[0] if len(re.findall("[,0-9]+",x))>0 else np.nan).str.replace(",","").astype(float).value_counts(dropna = False)

# %%
df.empty_weight = df.empty_weight.astype(str).apply(lambda x : re.findall("[,0-9]+",x)[0] if len(re.findall("[,0-9]+",x))>0 else np.nan).str.replace(",","").astype(float)

# %%
df.empty_weight.value_counts(dropna = False)
# Out:
# NaN        10872
# 1395.0       233
# 1055.0       224
# 1423.0       216
# 1165.0       200
# 1320.0       192
# 1280.0       179
# 1090.0       129
# 1370.0       120
# 1615.0       113
# 1472.0       112
# 1310.0       112
# 1315.0       109
# 1350.0       108
# 1701.0       107
# 1050.0       104
# 905.0         97
# 1390.0        94
# 1485.0        92
# 1735.0        90
# 1295.0        88
# 1355.0        86
# 1275.0        84
# 1345.0        83
# 1430.0        83
# 1425.0        81
# 1040.0        80
# 1365.0        79
# 1245.0        79
# 1500.0        78
# 1135.0        77
# 980.0         76
# 1505.0        75
# 1255.0        73
# 975.0         70
# 1305.0        70
# 1015.0        69
# 1180.0        69
# 1065.0        67
# 1445.0        67
# 1680.0        65
# 1375.0        64
# 1439.0        64
# 1115.0        63
# 1045.0        61
# 1260.0        60
# 1733.0        60
# 1465.0        58
# 1575.0        58
# 1480.0        58
# 1265.0        57
# 950.0         56
# ...

# %%
df.empty_weight.dtype
# Out:
# dtype('float64')

# %%
show_null_perc(df.empty_weight)
# Out:
# 37.97

# %% [markdown]
# ## model_code

# %%
df.model_code.value_counts(dropna=False)
# Out:
# NaN                   20263
# [\n, 8212/AFJ, \n]       75
# [\n, 1727/AAM, \n]       64
# [\n, 1349/AGI, \n]       61
# [\n, 1889/ABU, \n]       55
# [\n, 7104/AAL, \n]       53
# [\n, 8566/BOF, \n]       48
# [\n, 8566/BTG, \n]       44
# [\n, 1727/AUD, \n]       43
# [\n, 8004/ANL, \n]       42
# [\n, 8004/ASO, \n]       42
# [\n, 5013/AOF, \n]       41
# [\n, 9101/BGR, \n]       40
# [\n, 2228/ABJ, \n]       39
# [\n, 8566/BOG, \n]       38
# [\n, 9101/BMJ, \n]       38
# [\n, 5013/AOS, \n]       37
# [\n, 1844/AKF, \n]       37
# [\n, 0000/000, \n]       35
# [\n, 7593/AOB, \n]       34
# [\n, 8566/BQQ, \n]       32
# [\n, 8566/BUF, \n]       32
# [\n, 1889/ABT, \n]       31
# [\n, 9101/BFG, \n]       30
# [\n, 3333/BNX, \n]       29
# [\n, 5013/ALR, \n]       28
# [\n, 1028/AAI, \n]       28
# [\n, 8004/APL, \n]       28
# [\n, 8212/AFG, \n]       28
# [\n, 8566/BTQ, \n]       27
# [\n, 1844/AAN, \n]       26
# [\n, 9101/BFH, \n]       26
# [\n, 8004/ASR, \n]       26
# ...

# %%
df.model_code = pick_from_list(df.model_code)

# %%
df.model_code.value_counts(dropna=False)
# Out:
# NaN           20263
#  8212/AFJ        75
#  1727/AAM        64
#  1349/AGI        61
#  1889/ABU        55
#  7104/AAL        53
#  8566/BOF        48
#  8566/BTG        44
#  1727/AUD        43
#  8004/ANL        42
#  8004/ASO        42
#  5013/AOF        41
#  9101/BGR        40
#  2228/ABJ        39
#  8566/BOG        38
#  9101/BMJ        38
#  5013/AOS        37
#  1844/AKF        37
#  0000/000        35
#  7593/AOB        34
#  8566/BQQ        32
#  8566/BUF        32
#  1889/ABT        31
#  9101/BFG        30
#  3333/BNX        29
#  5013/ALR        28
#  1028/AAI        28
#  8004/APL        28
#  8212/AFG        28
#  8566/BTQ        27
#  1844/AAN        26
#  9101/BFH        26
#  8004/ASR        26
#  8566/BUE        26
#  9101/BMK        26
#  9101/BIL        26
#  1028/AAR        25
#  7593/AMY        25
#  1028/AAM        25
#  7593/ARJ        25
#  1028/AAJ        24
#  8004/ASQ        24
#  1349/AEX        24
#  9101/BJB        24
#  3333/BOK        24
# ...

# %%
# type(pick_from_list(df.model_code)[0]) #check NaN types are preserved

# %%
df.model_code.dtype
# Out:
# dtype('O')

# %%
type(df.model_code[0])
# Out:
# float

# %%
type(df.model_code[2220])
# Out:
# str

# %%
show_null_perc(df.model_code)
# Out:
# 70.78

# %%
df.drop("model_code",axis=1,inplace=True)

# %% [markdown]
# ## general_inspection
# Drop? I have replaced New by 2027. Using the difference between now(2022) and next inspection date I will calculate remaining year.

# %%
df.general_inspection.value_counts(dropna=False)
# Out:
# NaN        16376
# New         5883
# 05/2023      286
# 08/2023      280
# 03/2023      268
# 06/2023      266
# 04/2023      262
# 09/2023      255
# 07/2023      254
# 06/2024      216
# 05/2024      212
# 01/2023      210
# 02/2023      209
# 03/2024      207
# 07/2024      203
# 08/2024      187
# 09/2024      182
# 11/2023      176
# 01/2024      164
# 02/2024      163
# 04/2024      162
# 12/2023      160
# 12/2022      159
# 10/2023      155
# 06/2025      147
# 11/2022      131
# 08/2025      122
# 07/2025      110
# 09/2022       96
# 03/2025       95
# 05/2025       93
# 10/2022       90
# 04/2025       89
# 01/2025       75
# 02/2025       66
# 09/2025       65
# 10/2024       64
# 08/2022       64
# 12/2024       61
# 11/2024       50
# 06/2022       42
# 07/2022       41
# 04/2022       34
# 03/2022       25
# 05/2022       22
# 10/2021       17
# 11/2021       11
# 01/2022       10
# 07/2021       10
# 09/2021        8
# 08/2021        7
# 12/2021        7
# ...

# %%
type(df.general_inspection[15])
# Out:
# str

# %%
df.general_inspection = df.general_inspection.astype(str).str.replace("New", "11/2027").apply(lambda x : x.split("/")[1] if len(x.split("/"))>1 else np.nan).astype("float")

# %%
show_null_perc(df.general_inspection)
# Out:
# 57.2

# %%
df.general_inspection.dtype
# Out:
# dtype('float64')

# %% [markdown]
# Create a new column for remaining inspection year

# %%
df["remain_inspect_year"] = df.general_inspection - 2022

# %%
show_null_perc(df.remain_inspect_year)
# Out:
# 57.2

# %%
df.remain_inspect_year.value_counts(dropna=False)
# Out:
#  NaN    16376
#  5.0     5885
#  1.0     2781
#  2.0     1871
#  3.0      868
#  0.0      720
# -1.0       73
#  4.0       23
# -2.0       18
# -3.0        8
# -4.0        3
# -5.0        3
# -9.0        1
# Name: remain_inspect_year, dtype: int64

# %%
df.drop("remain_inspect_year",axis=1,inplace=True)

# %%
df.drop("general_inspection",axis=1,inplace=True)

# %% [markdown]
# ## full_service_history

# %%
df.full_service_history.value_counts(dropna=False)
# Out:
# NaN    16065
# Yes    12565
# Name: full_service_history, dtype: int64

# %%
df.full_service_history.dtype
# Out:
# dtype('O')

# %%
show_null_perc(df.full_service_history)
# Out:
# 56.11

# %% [markdown]
# ## non_smoker_vehicle

# %%
df.non_smoker_vehicle.value_counts(dropna=False)
# Out:
# NaN    17036
# Yes    11594
# Name: non_smoker_vehicle, dtype: int64

# %%
df.non_smoker_vehicle.dtype
# Out:
# dtype('O')

# %%
show_null_perc(df.non_smoker_vehicle)
# Out:
# 59.5

# %%
df.drop("non_smoker_vehicle",axis=1,inplace=True)

# %% [markdown]
# ## emission_class

# %%
df.emission_class.value_counts(dropna=False)
# Out:
# NaN             10771
# Euro 6           6418
# Euro 6d-TEMP     3399
# Euro 6d          2858
# Euro 5           2389
# Euro 4           1743
# Euro 3            523
# Euro 2            217
# Euro 1            172
# Euro 6c           140
# Name: emission_class, dtype: int64

# %%
df.emission_class.dtype
# Out:
# dtype('O')

# %%
show_null_perc(df.emission_class)
# Out:
# 37.62

# %%
show_null_perc(df.co_emissions)
# Out:
# 35.05

# %%
df[df["co_emissions"].isnull() & df["emission_class"].notnull()][["co_emissions","emission_class"]].index.shape
# Out:
# (1722,)

# %% [markdown]
# ## emissions_sticker
#
# 4 (Green)
#
# 1 (No sticker)
#
# 3 (Yellow)
#
# 2 (Red)

# %%
df.emissions_sticker.value_counts(dropna=False)
# Out:
# NaN               19216
# 4 (Green)          9230
# 1 (No sticker)      176
# 3 (Yellow)            6
# 2 (Red)               2
# Name: emissions_sticker, dtype: int64

# %%
show_null_perc(df.emissions_sticker)
# Out:
# 67.12

# %%
df.emissions_sticker = df.emissions_sticker.astype(str).apply(lambda x : re.findall("[0-9]+",x)[0] if len(re.findall("[0-9]+",x))>0 else np.nan).astype(float)

# %%
df.emissions_sticker.value_counts(dropna=False)
# Out:
# NaN    19216
# 4.0     9230
# 1.0      176
# 3.0        6
# 2.0        2
# Name: emissions_sticker, dtype: int64

# %%
df.emissions_sticker.dtype
# Out:
# dtype('float64')

# %%
df[df["co_emissions"].isnull() & df["emissions_sticker"].notnull()][["co_emissions","emissions_sticker"]].index.shape
# Out:
# (1073,)

# %%
df.drop("emissions_sticker",axis=1,inplace=True)

# %% [markdown]
# ## upholstery_colour

# %%
df.upholstery_colour.value_counts(dropna=False)
# Out:
# NaN       14061
# Black     10416
# Grey       2038
# Other      1003
# Beige       466
# Brown       275
# Red         159
# White        93
# Blue         82
# Orange       23
# Green         8
# Yellow        6
# Name: upholstery_colour, dtype: int64

# %%
df.upholstery_colour.value_counts(dropna=False).index.shape
# Out:
# (12,)

# %%
show_null_perc(df.upholstery_colour)
# Out:
# 49.11

# %%
df.upholstery_colour.dtype
# Out:
# dtype('O')

# %% [markdown]
# ## previous_owner
# Last element in the list shows number of previous owner (choose and use it)

# %%
df.previous_owner.value_counts(dropna=False)
# Out:
# NaN                           14615
# [[50 km, 06/2022], 1]            64
# [[10 km, 08/2022], 1]            59
# [[10 km, 07/2022], 1]            45
# [[10 km, 09/2022], 1]            38
# [[10 km, 05/2022], 1]            37
# [[10 km, 06/2022], 1]            34
# [[20 km, 08/2022], 1]            21
# [[15 km, 09/2022], 1]            19
# [[100 km, 09/2022], 1]           17
# [[20 km, 07/2022], 1]            17
# [[10 km, 03/2022], 1]            15
# [[100 km, 08/2022], 1]           14
# [[5,000 km, 05/2022], 1]         14
# [[10 km, 01/2022], 1]            14
# [[10 km, 04/2022], 1]            12
# [[5 km, 07/2022], 1]             12
# [[10 km, 02/2022], 1]            12
# [[1,000 km, 07/2022], 1]         11
# [[35 km, 08/2022], 1]            11
# [[20 km, 09/2022], 1]            11
# [[9,900 km, 09/2022], 1]         10
# [[15 km, 08/2022], 1]            10
# [[2,001 km, 09/2022], 1]         10
# [[100 km, 07/2022], 1]           10
# [[3,000 km, 04/2022], 1]         10
# ...

# %%
show_null_perc(df.previous_owner)
# Out:
# 51.05

# %%
df.previous_owner = [i[1] if type(i)==list else i for i in df.previous_owner]

# %%
show_null_perc(df.previous_owner)
# Out:
# 51.05

# %%
df.previous_owner.value_counts(dropna=False)
# Out:
# NaN    14615
# 1       9746
# 2       3221
# 3        699
# 4        184
# 5         69
# 6         37
# 7         22
# 8         16
# 9         14
# 12         3
# 10         2
# 14         1
# 13         1
# Name: previous_owner, dtype: int64

# %%
df.previous_owner = df.previous_owner.astype(float)

# %%
df.previous_owner.dtype
# Out:
# dtype('float64')

# %% [markdown]
# ## energy_efficiency_class

# %%
df.energy_efficiency_class.value_counts(dropna=False)
# Out:
# NaN     20826
# B        2090
# A        1687
# C        1133
# A+       1089
# D         636
# A+++      375
# G         309
# E         271
# F         147
# A++        67
# Name: energy_efficiency_class, dtype: int64

# %%
show_null_perc(df.energy_efficiency_class)
# Out:
# 72.74

# %%
df.drop("energy_efficiency_class",axis=1,inplace=True)

# %% [markdown]
# ## co_efficiency

# %%
df.co_efficiency.value_counts(dropna=False)
# Out:
# NaN                                                                                           20826
# Calculated on basis of measured CO₂-emissions taking into account the mass of the vehicle.     7804
# Name: co_efficiency, dtype: int64

# %%
show_null_perc(df.co_efficiency)
# Out:
# 72.74

# %%
df.drop("co_efficiency",axis=1,inplace=True)

# %% [markdown]
# #### Check columnsif they contains list type (to get rid of dublicates)

# %%
# list_columns_final = []
# for i in df.columns:
#     for y in df[i].sample(25000):
#         if "]" in str(y):
#             if i not in list_columns_final:
#                 list_columns_final.append(i) 
list_columns_final = []

for i in df.columns:
    for y in df[i].sample(25000):
        if type(y)==list:
            if i not in list_columns_init:
                list_columns_init.append(i)

# %%
list_columns_final
# Out:
# []

# %%
df.head().T
# Out:
#                                   0                 1              2  \
# make                  Mercedes-Benz     Mercedes-Benz  Mercedes-Benz
# location                         ES                ES             ES
# price                       16950.0           80900.0        69900.0
# body_type                  Compact           Compact        Compact
# type                          Used    Pre-registered           Used
# doors                           5.0               4.0            5.0
# warranty                       24.0              24.0           12.0
# mileage                    120200.0            5000.0        18900.0
# gearbox                      Manual         Automatic      Automatic
# fuel_type                    diesel          electric        benzine
# colour                        Black               NaN           Grey
# paint                      Metallic               NaN            NaN
# seller                       Dealer            Dealer         Dealer
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 28630 entries, 0 to 29478
# Data columns (total 35 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   make                  28630 non-null  object
#  1   location              28630 non-null  object
#  2   price                 28630 non-null  float64
#  3   body_type             28630 non-null  object
#  4   type                  28630 non-null  object
#  5   doors                 28271 non-null  float64
#  6   warranty              13465 non-null  float64
#  7   mileage               28629 non-null  float64
#  8   gearbox               28382 non-null  object
#  9   fuel_type             26843 non-null  object
#  10  colour                26906 non-null  object
#  11  paint                 14495 non-null  object
#  12  seller                28630 non-null  object
#  13  seats                 25505 non-null  float64
# ...

# %% [markdown]
# ## Check dublicated

# %%
df.duplicated().sum()
# Out:
# 4078

# %%
df.drop_duplicates(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 24552 entries, 0 to 29478
# Data columns (total 35 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   make                  24552 non-null  object
#  1   location              24552 non-null  object
#  2   price                 24552 non-null  float64
#  3   body_type             24552 non-null  object
#  4   type                  24552 non-null  object
#  5   doors                 24213 non-null  float64
#  6   warranty              10524 non-null  float64
#  7   mileage               24551 non-null  float64
#  8   gearbox               24318 non-null  object
#  9   fuel_type             22980 non-null  object
#  10  colour                23117 non-null  object
#  11  paint                 13261 non-null  object
#  12  seller                24552 non-null  object
#  13  seats                 22043 non-null  float64
# ...

# %% [markdown]
# ## End of first part

# %% [markdown]
# ### export data after cleaning

# %%
df.to_csv("final_scout_cln_with_nulls.csv", index=False)
